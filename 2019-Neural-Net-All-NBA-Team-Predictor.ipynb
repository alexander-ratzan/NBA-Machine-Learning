# %% [markdown]
# # Machine Learning Predictions for the 2018-19 All-NBA team
#
# Every NBA season a panel of sportswriters and broadcasters throughout the United States and Canada vote on the All-NBA teams. The All-NBA teams acknowledge the best players in the NBA by position. There are 3 ranked teams (1st, 2nd, 3rd) each consisting of 2 guards, 2 forwards, and 1 center, combining for a total of 15 All-NBA players. Not only is it a huge honor to be selected to an All-NBA team, but it is also important for contract negotiations as players can only be paid certain amounts if they achieve All-NBA accolades for a certain number of years.
#
# With this in mind, wouldn't it be cool for General Managers to predict who will make the All-NBA teams each year based on players stat lines? Such a predictor could provide valuable information on contract negotiations as well as how trades might affect revenue stream.
#
# This notebook explores exactly that... how well can we leverage Machine Learning to build a highly accurate All-NBA team predictor.

# %% [markdown]
# ### To note:
# **You must use pip to install basketball_reference_web_scraper otherwise this notebook won't work. Install it using the following command: pip install basketball_reference_web_scraper**
#
# Note: I originally had an issue installing it which was solved by running the command like this:
# pip install basketball_reference_web_scraper --ignore-installed
#
# **Please run each cell in order!! The first cell takes a while to run since it is retrieving a lot of data. Just wait for it to finish**

# %% [markdown]
# ### See link for full NBA ML project presentation: https://docs.google.com/presentation/d/1GAcQrv--O6522p817_GfwxO8wyjRE0g2agpECrs6I0A/edit?usp=sharing
# Collaborators: Ari Hirsch (Columbia University), Jordan Ramos (Columbia University, github: jordanpramos)

# %% [markdown]
# ### Firstly, retrieving the data:
# I added in some calculated stats like field goal percentage and points. Also, if a player was moved midseason, I combined their totals from each team.

# %%
from basketball_reference_web_scraper import client
import collections
import copy
import pandas as pd

statsToAdd = ['games_played', 'games_started', 'minutes_played', 'made_field_goals', 'attempted_field_goals', 'made_three_point_field_goals', 'attempted_three_point_field_goals', 'made_free_throws', 'attempted_free_throws', 'offensive_rebounds', 'defensive_rebounds', 'assists', 'steals', 'blocks', 'turnovers', 'personal_fouls']

statDict = {}
for year in range(2001, 2020):
    yearPlayers = client.players_season_totals(season_end_year=year)
    playerIdList = [player['slug'] for player in yearPlayers]
    tradedPlayersIdList = [playerId for playerId, count in collections.Counter(playerIdList).items() if count > 1]
    for tradedPlayerId in tradedPlayersIdList:
        playerStatsList = []
        toDelete = []
        totalPlayerStats = {'slug': '', 'name': '', 'positions': 0, 'age': 0, 'team': 0, 'games_played': 0, 'games_started': 0, 'minutes_played': 0, 'made_field_goals': 0, 'attempted_field_goals': 0, 'made_three_point_field_goals': 0, 'attempted_three_point_field_goals': 0, 'made_free_throws': 0, 'attempted_free_throws': 0, 'offensive_rebounds': 0, 'defensive_rebounds': 0, 'assists': 0, 'steals': 0, 'blocks': 0, 'turnovers': 0, 'personal_fouls': 0}
        for idx, player in enumerate(yearPlayers):
            if tradedPlayerId == player['slug']:
                playerStatsList.append(player)
                toDelete.append(idx)
        for i in toDelete:
            yearPlayers.pop(toDelete[0])
        for playerTeamStats in playerStatsList:
            if totalPlayerStats['slug'] == '':
                totalPlayerStats['slug'] = playerTeamStats['slug']
            if totalPlayerStats['name'] == '':
                totalPlayerStats['name'] = playerTeamStats['name']
            if totalPlayerStats['positions'] == 0:
                totalPlayerStats['positions'] = playerTeamStats['positions']
            if totalPlayerStats['age'] == 0:
                totalPlayerStats['age'] = playerTeamStats['age']
            if totalPlayerStats['team'] == 0:
                totalPlayerStats['team'] = playerTeamStats['team']
            for statName in statsToAdd:
                totalPlayerStats[statName] = totalPlayerStats[statName] + playerTeamStats[statName]
        yearPlayers.append(totalPlayerStats)
        for player in yearPlayers:
            #center = 1, forward = 2, guard = 3
             
            positionstring = str(player['positions'])
            #print(positionstring)

            if 'CENTER' in positionstring: # 8, -1
                 player['positions'] = 1
            elif 'FORWARD' in positionstring:
                player['positions'] = 2
            elif 'GUARD' in positionstring:
                player['positions'] = 3
            
            if(player['attempted_field_goals'] != 0):
                player['effective_field_goal_percentage'] = (player['made_field_goals'] + (.5 * player['made_three_point_field_goals'])) / player['attempted_field_goals']
            else:
                player['effective_field_goal_percentage'] = 0
            player['total_points'] = (player['made_three_point_field_goals'] * 3) + ((player['made_field_goals'] - player['made_three_point_field_goals']) * 2) + (player['made_free_throws'])
            if(player['attempted_free_throws'] != 0):
                player['free_throw_percentage'] = player['made_free_throws'] / player['attempted_free_throws']
            else:
                player['free_throw_percentage'] = 0
    statDict[year] = yearPlayers

# %%
for year in range(2001, 2020):
    for game in client.season_schedule(season_end_year=year):
        for player in statDict[year]:
            if "team_games_played" in player and player["team_games_played"] >= 82:
                break
            if player["team"] == game["home_team"] or player["team"] == game["away_team"]:
                if "team_games_played" in player:
                    player["team_games_played"] += 1
                else:
                    player["team_games_played"] = 1
            if game["home_team_score"] > game["away_team_score"]:
                if player["team"] == game["home_team"]:
                    if "wins" in player:
                        player["wins"] += 1
                    else:
                        player["wins"] = 1
            else:
                if player["team"] == game["away_team"]:
                    if "wins" in player:
                        player["wins"] += 1
                    else:
                        player["wins"] = 1

# %% [markdown]
# A dictionary containing all player stats from 2001 is returned and the most recent season (2019) is removed. This will serve as our training data. Our testing data will be the dictionary of players and their stats for just the 2019 season.

# %%
currentStatDict = copy.deepcopy(statDict[2019])
statDict.pop(2019) #keep in statDict or remove data from statdict
# Out:
# [{'slug': 'abrinal01',
#   'name': 'Álex Abrines',
#   'positions': 3,
#   'age': 25,
#   'team': <Team.OKLAHOMA_CITY_THUNDER: 'OKLAHOMA CITY THUNDER'>,
#   'games_played': 31,
#   'games_started': 2,
#   'minutes_played': 588,
#   'made_field_goals': 56,
#   'attempted_field_goals': 157,
#   'made_three_point_field_goals': 41,
#   'attempted_three_point_field_goals': 127,
#   'made_free_throws': 12,
#   'attempted_free_throws': 13,
#   'offensive_rebounds': 5,
#   'defensive_rebounds': 43,
#   'assists': 20,
#   'steals': 17,
#   'blocks': 6,
#   'turnovers': 14,
#   'personal_fouls': 53,
#   'points': 165,
#   'effective_field_goal_percentage': 0.4872611464968153,
#   'total_points': 165,
#   'free_throw_percentage': 0.9230769230769231,
#   'team_games_played': 82,
#   'wins': 49},
#  {'slug': 'acyqu01',
#   'name': 'Quincy Acy',
#   'positions': 2,
#   'age': 28,
#   'team': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'games_played': 10,
#   'games_started': 0,
#   'minutes_played': 123,
#   'made_field_goals': 4,
#   'attempted_field_goals': 18,
#   'made_three_point_field_goals': 2,
#   'attempted_three_point_field_goals': 15,
#   'made_free_throws': 7,
#   'attempted_free_throws': 10,
#   'offensive_rebounds': 3,
#   'defensive_rebounds': 22,
#   'assists': 8,
#   'steals': 1,
#   'blocks': 4,
#   'turnovers': 4,
#   'personal_fouls': 24,
#   'points': 17,
#   'effective_field_goal_percentage': 0.2777777777777778,
#   'total_points': 17,
#   'free_throw_percentage': 0.7,
#   'team_games_played': 82,
#   'wins': 19},
#  {'slug': 'adamsja01',
#   'name': 'Jaylen Adams',
#   'positions': 3,
#   'age': 22,
#   'team': <Team.ATLANTA_HAWKS: 'ATLANTA HAWKS'>,
#   'games_played': 34,
#   'games_started': 1,
#   'minutes_played': 428,
#   'made_field_goals': 38,
#   'attempted_field_goals': 110,
#   'made_three_point_field_goals': 25,
#   'attempted_three_point_field_goals': 74,
#   'made_free_throws': 7,
#   'attempted_free_throws': 9,
#   'offensive_rebounds': 11,
#   'defensive_rebounds': 49,
#   'assists': 65,
#   'steals': 14,
#   'blocks': 5,
#   'turnovers': 28,
#   'personal_fouls': 45,
#   'points': 108,
#   'effective_field_goal_percentage': 0.4590909090909091,
#   'total_points': 108,
#   'free_throw_percentage': 0.7777777777777778,
#   'team_games_played': 81,
#   'wins': 29},
#  {'slug': 'adamsst01',
#   'name': 'Steven Adams',
#   'positions': 1,
#   'age': 25,
#   'team': <Team.OKLAHOMA_CITY_THUNDER: 'OKLAHOMA CITY THUNDER'>,
#   'games_played': 80,
#   'games_started': 80,
#   'minutes_played': 2669,
#   'made_field_goals': 481,
#   'attempted_field_goals': 809,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 2,
#   'made_free_throws': 146,
#   'attempted_free_throws': 292,
#   'offensive_rebounds': 391,
#   'defensive_rebounds': 369,
#   'assists': 124,
#   'steals': 117,
#   'blocks': 76,
#   'turnovers': 135,
#   'personal_fouls': 204,
#   'points': 1108,
#   'effective_field_goal_percentage': 0.5945611866501854,
#   'total_points': 1108,
#   'free_throw_percentage': 0.5,
#   'team_games_played': 80,
#   'wins': 47},
#  {'slug': 'adebaba01',
#   'name': 'Bam Adebayo',
#   'positions': 1,
#   'age': 21,
#   'team': <Team.MIAMI_HEAT: 'MIAMI HEAT'>,
#   'games_played': 82,
#   'games_started': 28,
#   'minutes_played': 1913,
#   'made_field_goals': 280,
#   'attempted_field_goals': 486,
#   'made_three_point_field_goals': 3,
#   'attempted_three_point_field_goals': 15,
#   'made_free_throws': 166,
#   'attempted_free_throws': 226,
#   'offensive_rebounds': 165,
#   'defensive_rebounds': 432,
#   'assists': 184,
#   'steals': 71,
#   'blocks': 65,
#   'turnovers': 121,
#   'personal_fouls': 203,
#   'points': 729,
#   'effective_field_goal_percentage': 0.5792181069958847,
#   'total_points': 729,
#   'free_throw_percentage': 0.7345132743362832,
#   'team_games_played': 81,
#   'wins': 39},
#  {'slug': 'adelde01',
#   'name': 'Deng Adel',
#   'positions': 2,
#   'age': 21,
#   'team': <Team.CLEVELAND_CAVALIERS: 'CLEVELAND CAVALIERS'>,
#   'games_played': 19,
#   'games_started': 3,
#   'minutes_played': 194,
#   'made_field_goals': 11,
#   'attempted_field_goals': 36,
#   'made_three_point_field_goals': 6,
#   'attempted_three_point_field_goals': 23,
#   'made_free_throws': 4,
#   'attempted_free_throws': 4,
#   'offensive_rebounds': 3,
#   'defensive_rebounds': 16,
#   'assists': 5,
#   'steals': 1,
#   'blocks': 4,
#   'turnovers': 6,
#   'personal_fouls': 13,
#   'points': 32,
#   'effective_field_goal_percentage': 0.3888888888888889,
#   'total_points': 32,
#   'free_throw_percentage': 1.0,
#   'team_games_played': 82,
#   'wins': 19},
#  {'slug': 'akoonde01',
#   'name': 'DeVaughn Akoon-Purcell',
#   'positions': 3,
#   'age': 25,
#   'team': <Team.DENVER_NUGGETS: 'DENVER NUGGETS'>,
#   'games_played': 7,
#   'games_started': 0,
#   'minutes_played': 22,
#   'made_field_goals': 3,
#   'attempted_field_goals': 10,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 4,
#   'made_free_throws': 1,
#   'attempted_free_throws': 2,
#   'offensive_rebounds': 1,
#   'defensive_rebounds': 3,
#   'assists': 6,
#   'steals': 2,
#   'blocks': 0,
#   'turnovers': 2,
#   'personal_fouls': 4,
#   'points': 7,
#   'effective_field_goal_percentage': 0.3,
#   'total_points': 7,
#   'free_throw_percentage': 0.5,
#   'team_games_played': 80,
#   'wins': 53},
#  {'slug': 'aldrila01',
#   'name': 'LaMarcus Aldridge',
#   'positions': 1,
#   'age': 33,
#   'team': <Team.SAN_ANTONIO_SPURS: 'SAN ANTONIO SPURS'>,
#   'games_played': 81,
#   'games_started': 81,
#   'minutes_played': 2687,
#   'made_field_goals': 684,
#   'attempted_field_goals': 1319,
#   'made_three_point_field_goals': 10,
#   'attempted_three_point_field_goals': 42,
#   'made_free_throws': 349,
#   'attempted_free_throws': 412,
#   'offensive_rebounds': 251,
#   'defensive_rebounds': 493,
#   'assists': 194,
#   'steals': 43,
#   'blocks': 107,
#   'turnovers': 144,
#   'personal_fouls': 179,
#   'points': 1727,
#   'effective_field_goal_percentage': 0.5223654283548143,
#   'total_points': 1727,
#   'free_throw_percentage': 0.8470873786407767,
#   'team_games_played': 81,
#   'wins': 47},
#  {'slug': 'alkinra01',
#   'name': 'Rawle Alkins',
#   'positions': 3,
#   'age': 21,
#   'team': <Team.CHICAGO_BULLS: 'CHICAGO BULLS'>,
#   'games_played': 10,
#   'games_started': 1,
#   'minutes_played': 120,
#   'made_field_goals': 13,
#   'attempted_field_goals': 39,
#   'made_three_point_field_goals': 3,
#   'attempted_three_point_field_goals': 12,
#   'made_free_throws': 8,
#   'attempted_free_throws': 12,
#   'offensive_rebounds': 11,
#   'defensive_rebounds': 15,
#   'assists': 13,
#   'steals': 1,
#   'blocks': 0,
#   'turnovers': 8,
#   'personal_fouls': 7,
#   'points': 37,
#   'effective_field_goal_percentage': 0.3717948717948718,
#   'total_points': 37,
#   'free_throw_percentage': 0.6666666666666666,
#   'team_games_played': 80,
#   'wins': 22},
#  {'slug': 'allengr01',
#   'name': 'Grayson Allen',
#   'positions': 3,
#   'age': 23,
#   'team': <Team.UTAH_JAZZ: 'UTAH JAZZ'>,
#   'games_played': 38,
#   'games_started': 2,
#   'minutes_played': 416,
#   'made_field_goals': 67,
#   'attempted_field_goals': 178,
#   'made_three_point_field_goals': 32,
#   'attempted_three_point_field_goals': 99,
#   'made_free_throws': 45,
#   'attempted_free_throws': 60,
#   'offensive_rebounds': 3,
#   'defensive_rebounds': 20,
#   'assists': 25,
#   'steals': 6,
#   'blocks': 6,
#   'turnovers': 33,
#   'personal_fouls': 47,
#   'points': 211,
#   'effective_field_goal_percentage': 0.46629213483146065,
#   'total_points': 211,
#   'free_throw_percentage': 0.75,
#   'team_games_played': 80,
#   'wins': 49},
#  {'slug': 'allenja01',
#   'name': 'Jarrett Allen',
#   'positions': 1,
#   'age': 20,
#   'team': <Team.BROOKLYN_NETS: 'BROOKLYN NETS'>,
#   'games_played': 80,
#   'games_started': 80,
#   'minutes_played': 2096,
#   'made_field_goals': 335,
#   'attempted_field_goals': 568,
#   'made_three_point_field_goals': 6,
#   'attempted_three_point_field_goals': 45,
#   'made_free_throws': 197,
#   'attempted_free_throws': 278,
#   'offensive_rebounds': 191,
#   'defensive_rebounds': 481,
#   'assists': 110,
#   'steals': 43,
#   'blocks': 120,
#   'turnovers': 103,
#   'personal_fouls': 184,
#   'points': 873,
#   'effective_field_goal_percentage': 0.5950704225352113,
#   'total_points': 873,
#   'free_throw_percentage': 0.7086330935251799,
#   'team_games_played': 81,
#   'wins': 41},
#  {'slug': 'allenka01',
#   'name': 'Kadeem Allen',
#   'positions': 3,
#   'age': 26,
#   'team': <Team.NEW_YORK_KNICKS: 'NEW YORK KNICKS'>,
#   'games_played': 19,
#   'games_started': 1,
#   'minutes_played': 416,
#   'made_field_goals': 65,
#   'attempted_field_goals': 141,
#   'made_three_point_field_goals': 17,
#   'attempted_three_point_field_goals': 36,
#   'made_free_throws': 42,
#   'attempted_free_throws': 54,
#   'offensive_rebounds': 8,
#   'defensive_rebounds': 43,
#   'assists': 76,
#   'steals': 16,
#   'blocks': 4,
#   'turnovers': 26,
#   'personal_fouls': 46,
#   'points': 189,
#   'effective_field_goal_percentage': 0.5212765957446809,
#   'total_points': 189,
#   'free_throw_percentage': 0.7777777777777778,
#   'team_games_played': 80,
#   'wins': 16},
#  {'slug': 'aminual01',
#   'name': 'Al-Farouq Aminu',
#   'positions': 2,
#   'age': 28,
#   'team': <Team.PORTLAND_TRAIL_BLAZERS: 'PORTLAND TRAIL BLAZERS'>,
#   'games_played': 81,
#   'games_started': 81,
#   'minutes_played': 2292,
#   'made_field_goals': 257,
#   'attempted_field_goals': 593,
#   'made_three_point_field_goals': 96,
#   'attempted_three_point_field_goals': 280,
#   'made_free_throws': 150,
#   'attempted_free_throws': 173,
#   'offensive_rebounds': 112,
#   'defensive_rebounds': 498,
#   'assists': 104,
#   'steals': 68,
#   'blocks': 33,
#   'turnovers': 72,
#   'personal_fouls': 143,
#   'points': 760,
#   'effective_field_goal_percentage': 0.5143338954468802,
#   'total_points': 760,
#   'free_throw_percentage': 0.8670520231213873,
#   'team_games_played': 80,
#   'wins': 51},
#  {'slug': 'anderju01',
#   'name': 'Justin Anderson',
#   'positions': 2,
#   'age': 25,
#   'team': <Team.ATLANTA_HAWKS: 'ATLANTA HAWKS'>,
#   'games_played': 48,
#   'games_started': 4,
#   'minutes_played': 463,
#   'made_field_goals': 64,
#   'attempted_field_goals': 157,
#   'made_three_point_field_goals': 24,
#   'attempted_three_point_field_goals': 77,
#   'made_free_throws': 26,
#   'attempted_free_throws': 35,
#   'offensive_rebounds': 24,
#   'defensive_rebounds': 60,
#   'assists': 23,
#   'steals': 22,
#   'blocks': 13,
#   'turnovers': 23,
#   'personal_fouls': 48,
#   'points': 178,
#   'effective_field_goal_percentage': 0.4840764331210191,
#   'total_points': 178,
#   'free_throw_percentage': 0.7428571428571429,
#   'team_games_played': 81,
#   'wins': 29},
#  {'slug': 'anderky01',
#   'name': 'Kyle Anderson',
#   'positions': 2,
#   'age': 25,
#   'team': <Team.MEMPHIS_GRIZZLIES: 'MEMPHIS GRIZZLIES'>,
#   'games_played': 43,
#   'games_started': 40,
#   'minutes_played': 1281,
#   'made_field_goals': 150,
#   'attempted_field_goals': 276,
#   'made_three_point_field_goals': 9,
#   'attempted_three_point_field_goals': 34,
#   'made_free_throws': 37,
#   'attempted_free_throws': 64,
#   'offensive_rebounds': 48,
#   'defensive_rebounds': 203,
#   'assists': 128,
#   'steals': 54,
#   'blocks': 37,
#   'turnovers': 58,
#   'personal_fouls': 112,
#   'points': 346,
#   'effective_field_goal_percentage': 0.5597826086956522,
#   'total_points': 346,
#   'free_throw_percentage': 0.578125,
#   'team_games_played': 80,
#   'wins': 32},
#  {'slug': 'anigbik01',
#   'name': 'Ike Anigbogu',
#   'positions': 1,
#   'age': 20,
#   'team': <Team.INDIANA_PACERS: 'INDIANA PACERS'>,
#   'games_played': 3,
#   'games_started': 0,
#   'minutes_played': 6,
#   'made_field_goals': 0,
#   'attempted_field_goals': 3,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 1,
#   'defensive_rebounds': 2,
#   'assists': 1,
#   'steals': 0,
#   'blocks': 1,
#   'turnovers': 1,
#   'personal_fouls': 0,
#   'points': 0,
#   'effective_field_goal_percentage': 0.0,
#   'total_points': 0,
#   'free_throw_percentage': 0,
#   'team_games_played': 81,
#   'wins': 47},
#  {'slug': 'antetgi01',
#   'name': 'Giannis Antetokounmpo',
#   'positions': 2,
#   'age': 24,
#   'team': <Team.MILWAUKEE_BUCKS: 'MILWAUKEE BUCKS'>,
#   'games_played': 72,
#   'games_started': 72,
#   'minutes_played': 2358,
#   'made_field_goals': 721,
#   'attempted_field_goals': 1247,
#   'made_three_point_field_goals': 52,
#   'attempted_three_point_field_goals': 203,
#   'made_free_throws': 500,
#   'attempted_free_throws': 686,
#   'offensive_rebounds': 159,
#   'defensive_rebounds': 739,
#   'assists': 424,
#   'steals': 92,
#   'blocks': 110,
#   'turnovers': 268,
#   'personal_fouls': 232,
#   'points': 1994,
#   'effective_field_goal_percentage': 0.599037690457097,
#   'total_points': 1994,
#   'free_throw_percentage': 0.7288629737609329,
#   'team_games_played': 81,
#   'wins': 60},
#  {'slug': 'antetko01',
#   'name': 'Kostas Antetokounmpo',
#   'positions': 2,
#   'age': 21,
#   'team': <Team.DALLAS_MAVERICKS: 'DALLAS MAVERICKS'>,
#   'games_played': 2,
#   'games_started': 0,
#   'minutes_played': 11,
#   'made_field_goals': 0,
#   'attempted_field_goals': 3,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 2,
#   'attempted_free_throws': 4,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 1,
#   'assists': 0,
#   'steals': 2,
#   'blocks': 0,
#   'turnovers': 1,
#   'personal_fouls': 0,
#   'points': 2,
#   'effective_field_goal_percentage': 0.0,
#   'total_points': 2,
#   'free_throw_percentage': 0.5,
#   'team_games_played': 80,
#   'wins': 32},
#  {'slug': 'anthoca01',
#   'name': 'Carmelo Anthony',
#   'positions': 2,
#   'age': 34,
#   'team': <Team.HOUSTON_ROCKETS: 'HOUSTON ROCKETS'>,
#   'games_played': 10,
#   'games_started': 2,
#   'minutes_played': 294,
#   'made_field_goals': 49,
#   'attempted_field_goals': 121,
#   'made_three_point_field_goals': 21,
#   'attempted_three_point_field_goals': 64,
#   'made_free_throws': 15,
#   'attempted_free_throws': 22,
#   'offensive_rebounds': 9,
#   'defensive_rebounds': 45,
#   'assists': 5,
#   'steals': 4,
#   'blocks': 7,
#   'turnovers': 8,
#   'personal_fouls': 32,
#   'points': 134,
#   'effective_field_goal_percentage': 0.49173553719008267,
#   'total_points': 134,
#   'free_throw_percentage': 0.6818181818181818,
#   'team_games_played': 81,
#   'wins': 53},
#  {'slug': 'anunoog01',
#   'name': 'OG Anunoby',
#   'positions': 2,
#   'age': 21,
#   'team': <Team.TORONTO_RAPTORS: 'TORONTO RAPTORS'>,
#   'games_played': 67,
#   'games_started': 6,
#   'minutes_played': 1352,
#   'made_field_goals': 183,
#   'attempted_field_goals': 404,
#   'made_three_point_field_goals': 67,
#   'attempted_three_point_field_goals': 202,
#   'made_free_throws': 36,
#   'attempted_free_throws': 62,
#   'offensive_rebounds': 58,
#   'defensive_rebounds': 139,
#   'assists': 47,
#   'steals': 46,
#   'blocks': 22,
#   'turnovers': 55,
#   'personal_fouls': 140,
#   'points': 469,
#   'effective_field_goal_percentage': 0.5358910891089109,
#   'total_points': 469,
#   'free_throw_percentage': 0.5806451612903226,
#   'team_games_played': 81,
#   'wins': 57},
#  {'slug': 'arcidry01',
#   'name': 'Ryan Arcidiacono',
#   'positions': 3,
#   'age': 24,
#   'team': <Team.CHICAGO_BULLS: 'CHICAGO BULLS'>,
#   'games_played': 81,
#   'games_started': 32,
#   'minutes_played': 1961,
#   'made_field_goals': 187,
#   'attempted_field_goals': 418,
#   'made_three_point_field_goals': 81,
#   'attempted_three_point_field_goals': 217,
#   'made_free_throws': 89,
#   'attempted_free_throws': 102,
#   'offensive_rebounds': 27,
#   'defensive_rebounds': 192,
#   'assists': 269,
#   'steals': 65,
#   'blocks': 4,
#   'turnovers': 63,
#   'personal_fouls': 171,
#   'points': 544,
#   'effective_field_goal_percentage': 0.5442583732057417,
#   'total_points': 544,
#   'free_throw_percentage': 0.8725490196078431,
#   'team_games_played': 80,
#   'wins': 22},
#  {'slug': 'augusdj01',
#   'name': 'D.J. Augustin',
#   'positions': 3,
#   'age': 31,
#   'team': <Team.ORLANDO_MAGIC: 'ORLANDO MAGIC'>,
#   'games_played': 81,
#   'games_started': 81,
#   'minutes_played': 2269,
#   'made_field_goals': 318,
#   'attempted_field_goals': 677,
#   'made_three_point_field_goals': 131,
#   'attempted_three_point_field_goals': 311,
#   'made_free_throws': 181,
#   'attempted_free_throws': 209,
#   'offensive_rebounds': 41,
#   'defensive_rebounds': 162,
#   'assists': 426,
#   'steals': 52,
#   'blocks': 4,
#   'turnovers': 128,
#   'personal_fouls': 115,
#   'points': 948,
#   'effective_field_goal_percentage': 0.5664697193500738,
#   'total_points': 948,
#   'free_throw_percentage': 0.8660287081339713,
#   'team_games_played': 81,
#   'wins': 41},
#  {'slug': 'aytonde01',
#   'name': 'Deandre Ayton',
#   'positions': 1,
#   'age': 20,
#   'team': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'games_played': 71,
#   'games_started': 70,
#   'minutes_played': 2183,
#   'made_field_goals': 509,
#   'attempted_field_goals': 870,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 4,
#   'made_free_throws': 141,
#   'attempted_free_throws': 189,
#   'offensive_rebounds': 223,
#   'defensive_rebounds': 506,
#   'assists': 125,
#   'steals': 61,
#   'blocks': 67,
#   'turnovers': 126,
#   'personal_fouls': 209,
#   'points': 1159,
#   'effective_field_goal_percentage': 0.5850574712643678,
#   'total_points': 1159,
#   'free_throw_percentage': 0.746031746031746,
#   'team_games_played': 81,
#   'wins': 19},
#  {'slug': 'bacondw01',
#   'name': 'Dwayne Bacon',
#   'positions': 3,
#   'age': 23,
#   'team': <Team.CHARLOTTE_HORNETS: 'CHARLOTTE HORNETS'>,
#   'games_played': 43,
#   'games_started': 13,
#   'minutes_played': 759,
#   'made_field_goals': 122,
#   'attempted_field_goals': 257,
#   'made_three_point_field_goals': 38,
#   'attempted_three_point_field_goals': 87,
#   'made_free_throws': 34,
#   'attempted_free_throws': 46,
#   'offensive_rebounds': 8,
#   'defensive_rebounds': 81,
#   'assists': 47,
#   'steals': 12,
#   'blocks': 5,
#   'turnovers': 18,
#   'personal_fouls': 72,
#   'points': 316,
#   'effective_field_goal_percentage': 0.5486381322957199,
#   'total_points': 316,
#   'free_throw_percentage': 0.7391304347826086,
#   'team_games_played': 81,
#   'wins': 39},
#  {'slug': 'baglema01',
#   'name': 'Marvin Bagley III',
#   'positions': 2,
#   'age': 19,
#   'team': <Team.SACRAMENTO_KINGS: 'SACRAMENTO KINGS'>,
#   'games_played': 62,
#   'games_started': 4,
#   'minutes_played': 1567,
#   'made_field_goals': 356,
#   'attempted_field_goals': 706,
#   'made_three_point_field_goals': 30,
#   'attempted_three_point_field_goals': 96,
#   'made_free_throws': 181,
#   'attempted_free_throws': 262,
#   'offensive_rebounds': 162,
#   'defensive_rebounds': 309,
#   'assists': 62,
#   'steals': 33,
#   'blocks': 59,
#   'turnovers': 98,
#   'personal_fouls': 120,
#   'points': 923,
#   'effective_field_goal_percentage': 0.5254957507082153,
#   'total_points': 923,
#   'free_throw_percentage': 0.6908396946564885,
#   'team_games_played': 81,
#   'wins': 39},
#  {'slug': 'baldwwa01',
#   'name': 'Wade Baldwin',
#   'positions': 3,
#   'age': 22,
#   'team': <Team.PORTLAND_TRAIL_BLAZERS: 'PORTLAND TRAIL BLAZERS'>,
#   'games_played': 16,
#   'games_started': 0,
#   'minutes_played': 94,
#   'made_field_goals': 10,
#   'attempted_field_goals': 33,
#   'made_three_point_field_goals': 2,
#   'attempted_three_point_field_goals': 9,
#   'made_free_throws': 8,
#   'attempted_free_throws': 11,
#   'offensive_rebounds': 2,
#   'defensive_rebounds': 13,
#   'assists': 12,
#   'steals': 1,
#   'blocks': 2,
#   'turnovers': 14,
#   'personal_fouls': 11,
#   'points': 30,
#   'effective_field_goal_percentage': 0.3333333333333333,
#   'total_points': 30,
#   'free_throw_percentage': 0.7272727272727273,
#   'team_games_played': 80,
#   'wins': 51},
#  {'slug': 'balllo01',
#   'name': 'Lonzo Ball',
#   'positions': 3,
#   'age': 21,
#   'team': <Team.LOS_ANGELES_LAKERS: 'LOS ANGELES LAKERS'>,
#   'games_played': 47,
#   'games_started': 45,
#   'minutes_played': 1423,
#   'made_field_goals': 185,
#   'attempted_field_goals': 456,
#   'made_three_point_field_goals': 75,
#   'attempted_three_point_field_goals': 228,
#   'made_free_throws': 20,
#   'attempted_free_throws': 48,
#   'offensive_rebounds': 54,
#   'defensive_rebounds': 197,
#   'assists': 255,
#   'steals': 69,
#   'blocks': 19,
#   'turnovers': 103,
#   'personal_fouls': 114,
#   'points': 465,
#   'effective_field_goal_percentage': 0.48793859649122806,
#   'total_points': 465,
#   'free_throw_percentage': 0.4166666666666667,
#   'team_games_played': 81,
#   'wins': 37},
#  {'slug': 'bambamo01',
#   'name': 'Mo Bamba',
#   'positions': 1,
#   'age': 20,
#   'team': <Team.ORLANDO_MAGIC: 'ORLANDO MAGIC'>,
#   'games_played': 47,
#   'games_started': 1,
#   'minutes_played': 766,
#   'made_field_goals': 117,
#   'attempted_field_goals': 243,
#   'made_three_point_field_goals': 21,
#   'attempted_three_point_field_goals': 70,
#   'made_free_throws': 37,
#   'attempted_free_throws': 63,
#   'offensive_rebounds': 64,
#   'defensive_rebounds': 169,
#   'assists': 39,
#   'steals': 13,
#   'blocks': 64,
#   'turnovers': 43,
#   'personal_fouls': 102,
#   'points': 292,
#   'effective_field_goal_percentage': 0.5246913580246914,
#   'total_points': 292,
#   'free_throw_percentage': 0.5873015873015873,
#   'team_games_played': 81,
#   'wins': 41},
#  {'slug': 'bareajo01',
#   'name': 'J.J. Barea',
#   'positions': 3,
#   'age': 34,
#   'team': <Team.DALLAS_MAVERICKS: 'DALLAS MAVERICKS'>,
#   'games_played': 38,
#   'games_started': 0,
#   'minutes_played': 752,
#   'made_field_goals': 161,
#   'attempted_field_goals': 385,
#   'made_three_point_field_goals': 38,
#   'attempted_three_point_field_goals': 128,
#   'made_free_throws': 55,
#   'attempted_free_throws': 78,
#   'offensive_rebounds': 13,
#   'defensive_rebounds': 82,
#   'assists': 211,
#   'steals': 22,
#   'blocks': 1,
#   'turnovers': 72,
#   'personal_fouls': 50,
#   'points': 415,
#   'effective_field_goal_percentage': 0.4675324675324675,
#   'total_points': 415,
#   'free_throw_percentage': 0.7051282051282052,
#   'team_games_played': 80,
#   'wins': 32},
#  {'slug': 'bartowi01',
#   'name': 'Will Barton',
#   'positions': 2,
#   'age': 28,
#   'team': <Team.DENVER_NUGGETS: 'DENVER NUGGETS'>,
#   'games_played': 43,
#   'games_started': 38,
#   'minutes_played': 1189,
#   'made_field_goals': 185,
#   'attempted_field_goals': 460,
#   'made_three_point_field_goals': 67,
#   'attempted_three_point_field_goals': 196,
#   'made_free_throws': 57,
#   'attempted_free_throws': 74,
#   'offensive_rebounds': 32,
#   'defensive_rebounds': 167,
#   'assists': 124,
#   'steals': 18,
#   'blocks': 22,
#   'turnovers': 65,
#   'personal_fouls': 82,
#   'points': 494,
#   'effective_field_goal_percentage': 0.475,
#   'total_points': 494,
#   'free_throw_percentage': 0.7702702702702703,
#   'team_games_played': 80,
#   'wins': 53},
#  {'slug': 'bateske01',
#   'name': 'Keita Bates-Diop',
#   'positions': 2,
#   'age': 23,
#   'team': <Team.MINNESOTA_TIMBERWOLVES: 'MINNESOTA TIMBERWOLVES'>,
#   'games_played': 30,
#   'games_started': 3,
#   'minutes_played': 503,
#   'made_field_goals': 60,
#   'attempted_field_goals': 142,
#   'made_three_point_field_goals': 13,
#   'attempted_three_point_field_goals': 52,
#   'made_free_throws': 18,
#   'attempted_free_throws': 28,
#   'offensive_rebounds': 16,
#   'defensive_rebounds': 67,
#   'assists': 17,
#   'steals': 18,
#   'blocks': 14,
#   'turnovers': 14,
#   'personal_fouls': 29,
#   'points': 151,
#   'effective_field_goal_percentage': 0.46830985915492956,
#   'total_points': 151,
#   'free_throw_percentage': 0.6428571428571429,
#   'team_games_played': 80,
#   'wins': 36},
#  {'slug': 'batumni01',
#   'name': 'Nicolas Batum',
#   'positions': 2,
#   'age': 30,
#   'team': <Team.CHARLOTTE_HORNETS: 'CHARLOTTE HORNETS'>,
#   'games_played': 75,
#   'games_started': 72,
#   'minutes_played': 2354,
#   'made_field_goals': 253,
#   'attempted_field_goals': 562,
#   'made_three_point_field_goals': 116,
#   'attempted_three_point_field_goals': 298,
#   'made_free_throws': 77,
#   'attempted_free_throws': 89,
#   'offensive_rebounds': 71,
#   'defensive_rebounds': 319,
#   'assists': 247,
#   'steals': 71,
#   'blocks': 43,
#   'turnovers': 117,
#   'personal_fouls': 140,
#   'points': 699,
#   'effective_field_goal_percentage': 0.5533807829181495,
#   'total_points': 699,
#   'free_throw_percentage': 0.8651685393258427,
#   'team_games_played': 81,
#   'wins': 39},
#  {'slug': 'bayleje01',
#   'name': 'Jerryd Bayless',
#   'positions': 3,
#   'age': 30,
#   'team': <Team.MINNESOTA_TIMBERWOLVES: 'MINNESOTA TIMBERWOLVES'>,
#   'games_played': 34,
#   'games_started': 6,
#   'minutes_played': 657,
#   'made_field_goals': 82,
#   'attempted_field_goals': 230,
#   'made_three_point_field_goals': 29,
#   'attempted_three_point_field_goals': 98,
#   'made_free_throws': 16,
#   'attempted_free_throws': 28,
#   'offensive_rebounds': 11,
#   'defensive_rebounds': 51,
#   'assists': 119,
#   'steals': 18,
#   'blocks': 2,
#   'turnovers': 32,
#   'personal_fouls': 56,
#   'points': 209,
#   'effective_field_goal_percentage': 0.41956521739130437,
#   'total_points': 209,
#   'free_throw_percentage': 0.5714285714285714,
#   'team_games_played': 80,
#   'wins': 36},
#  {'slug': 'baynear01',
#   'name': 'Aron Baynes',
#   'positions': 1,
#   'age': 32,
#   'team': <Team.BOSTON_CELTICS: 'BOSTON CELTICS'>,
#   'games_played': 51,
#   'games_started': 18,
#   'minutes_played': 821,
#   'made_field_goals': 105,
#   'attempted_field_goals': 223,
#   'made_three_point_field_goals': 21,
#   'attempted_three_point_field_goals': 61,
#   'made_free_throws': 53,
#   'attempted_free_throws': 62,
#   'offensive_rebounds': 88,
#   'defensive_rebounds': 152,
#   'assists': 57,
#   'steals': 12,
#   'blocks': 34,
#   'turnovers': 40,
#   'personal_fouls': 125,
#   'points': 284,
#   'effective_field_goal_percentage': 0.5179372197309418,
#   'total_points': 284,
#   'free_throw_percentage': 0.8548387096774194,
#   'team_games_played': 81,
#   'wins': 48},
#  {'slug': 'bazemke01',
#   'name': 'Kent Bazemore',
#   'positions': 3,
#   'age': 29,
#   'team': <Team.ATLANTA_HAWKS: 'ATLANTA HAWKS'>,
#   'games_played': 67,
#   'games_started': 35,
#   'minutes_played': 1643,
#   'made_field_goals': 278,
#   'attempted_field_goals': 691,
#   'made_three_point_field_goals': 96,
#   'attempted_three_point_field_goals': 300,
#   'made_free_throws': 127,
#   'attempted_free_throws': 175,
#   'offensive_rebounds': 37,
#   'defensive_rebounds': 224,
#   'assists': 152,
#   'steals': 89,
#   'blocks': 42,
#   'turnovers': 121,
#   'personal_fouls': 170,
#   'points': 779,
#   'effective_field_goal_percentage': 0.4717800289435601,
#   'total_points': 779,
#   'free_throw_percentage': 0.7257142857142858,
#   'team_games_played': 81,
#   'wins': 29},
#  {'slug': 'bealbr01',
#   'name': 'Bradley Beal',
#   'positions': 3,
#   'age': 25,
#   'team': <Team.WASHINGTON_WIZARDS: 'WASHINGTON WIZARDS'>,
#   'games_played': 82,
#   'games_started': 82,
#   'minutes_played': 3028,
#   'made_field_goals': 764,
#   'attempted_field_goals': 1609,
#   'made_three_point_field_goals': 209,
#   'attempted_three_point_field_goals': 596,
#   'made_free_throws': 362,
#   'attempted_free_throws': 448,
#   'offensive_rebounds': 89,
#   'defensive_rebounds': 322,
#   'assists': 448,
#   'steals': 121,
#   'blocks': 58,
#   'turnovers': 224,
#   'personal_fouls': 226,
#   'points': 2099,
#   'effective_field_goal_percentage': 0.5397762585456806,
#   'total_points': 2099,
#   'free_throw_percentage': 0.8080357142857143,
#   'team_games_played': 81,
#   'wins': 32},
#  {'slug': 'beaslma01',
#   'name': 'Malik Beasley',
#   'positions': 3,
#   'age': 22,
#   'team': <Team.DENVER_NUGGETS: 'DENVER NUGGETS'>,
#   'games_played': 81,
#   'games_started': 18,
#   'minutes_played': 1879,
#   'made_field_goals': 349,
#   'attempted_field_goals': 737,
#   'made_three_point_field_goals': 163,
#   'attempted_three_point_field_goals': 405,
#   'made_free_throws': 56,
#   'attempted_free_throws': 66,
#   'offensive_rebounds': 35,
#   'defensive_rebounds': 165,
#   'assists': 97,
#   'steals': 55,
#   'blocks': 10,
#   'turnovers': 55,
#   'personal_fouls': 116,
#   'points': 917,
#   'effective_field_goal_percentage': 0.5841248303934871,
#   'total_points': 917,
#   'free_throw_percentage': 0.8484848484848485,
#   'team_games_played': 80,
#   'wins': 53},
#  {'slug': 'beaslmi01',
#   'name': 'Michael Beasley',
#   'positions': 2,
#   'age': 30,
#   'team': <Team.LOS_ANGELES_LAKERS: 'LOS ANGELES LAKERS'>,
#   'games_played': 26,
#   'games_started': 2,
#   'minutes_played': 277,
#   'made_field_goals': 75,
#   'attempted_field_goals': 153,
#   'made_three_point_field_goals': 3,
#   'attempted_three_point_field_goals': 17,
#   'made_free_throws': 28,
#   'attempted_free_throws': 39,
#   'offensive_rebounds': 13,
#   'defensive_rebounds': 47,
#   'assists': 25,
#   'steals': 9,
#   'blocks': 10,
#   'turnovers': 27,
#   'personal_fouls': 42,
#   'points': 181,
#   'effective_field_goal_percentage': 0.5,
#   'total_points': 181,
#   'free_throw_percentage': 0.717948717948718,
#   'team_games_played': 81,
#   'wins': 37},
#  {'slug': 'belinma01',
#   'name': 'Marco Belinelli',
#   'positions': 3,
#   'age': 32,
#   'team': <Team.SAN_ANTONIO_SPURS: 'SAN ANTONIO SPURS'>,
#   'games_played': 79,
#   'games_started': 1,
#   'minutes_played': 1815,
#   'made_field_goals': 285,
#   'attempted_field_goals': 690,
#   'made_three_point_field_goals': 147,
#   'attempted_three_point_field_goals': 395,
#   'made_free_throws': 112,
#   'attempted_free_throws': 124,
#   'offensive_rebounds': 16,
#   'defensive_rebounds': 182,
#   'assists': 132,
#   'steals': 35,
#   'blocks': 8,
#   'turnovers': 72,
#   'personal_fouls': 121,
#   'points': 829,
#   'effective_field_goal_percentage': 0.5195652173913043,
#   'total_points': 829,
#   'free_throw_percentage': 0.9032258064516129,
#   'team_games_played': 81,
#   'wins': 47},
#  {'slug': 'belljo01',
#   'name': 'Jordan Bell',
#   'positions': 1,
#   'age': 24,
#   'team': <Team.GOLDEN_STATE_WARRIORS: 'GOLDEN STATE WARRIORS'>,
#   'games_played': 68,
#   'games_started': 3,
#   'minutes_played': 788,
#   'made_field_goals': 99,
#   'attempted_field_goals': 192,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 2,
#   'made_free_throws': 25,
#   'attempted_free_throws': 41,
#   'offensive_rebounds': 55,
#   'defensive_rebounds': 129,
#   'assists': 76,
#   'steals': 20,
#   'blocks': 51,
#   'turnovers': 42,
#   'personal_fouls': 80,
#   'points': 223,
#   'effective_field_goal_percentage': 0.515625,
#   'total_points': 223,
#   'free_throw_percentage': 0.6097560975609756,
#   'team_games_played': 80,
#   'wins': 56},
#  {'slug': 'bembrde01',
#   'name': "DeAndre' Bembry",
#   'positions': 3,
#   'age': 24,
#   'team': <Team.ATLANTA_HAWKS: 'ATLANTA HAWKS'>,
#   'games_played': 82,
#   'games_started': 15,
#   'minutes_played': 1931,
#   'made_field_goals': 275,
#   'attempted_field_goals': 616,
#   'made_three_point_field_goals': 50,
#   'attempted_three_point_field_goals': 173,
#   'made_free_throws': 87,
#   'attempted_free_throws': 136,
#   'offensive_rebounds': 54,
#   'defensive_rebounds': 304,
#   'assists': 202,
#   'steals': 105,
#   'blocks': 41,
#   'turnovers': 142,
#   'personal_fouls': 190,
#   'points': 687,
#   'effective_field_goal_percentage': 0.487012987012987,
#   'total_points': 687,
#   'free_throw_percentage': 0.6397058823529411,
#   'team_games_played': 81,
#   'wins': 29},
#  {'slug': 'bendedr01',
#   'name': 'Dragan Bender',
#   'positions': 2,
#   'age': 21,
#   'team': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'games_played': 46,
#   'games_started': 27,
#   'minutes_played': 826,
#   'made_field_goals': 88,
#   'attempted_field_goals': 197,
#   'made_three_point_field_goals': 22,
#   'attempted_three_point_field_goals': 101,
#   'made_free_throws': 32,
#   'attempted_free_throws': 54,
#   'offensive_rebounds': 34,
#   'defensive_rebounds': 149,
#   'assists': 56,
#   'steals': 18,
#   'blocks': 22,
#   'turnovers': 37,
#   'personal_fouls': 90,
#   'points': 230,
#   'effective_field_goal_percentage': 0.5025380710659898,
#   'total_points': 230,
#   'free_throw_percentage': 0.5925925925925926,
#   'team_games_played': 81,
#   'wins': 19},
#  {'slug': 'bertada02',
#   'name': 'Dairis Bertāns',
#   'positions': 3,
#   'age': 29,
#   'team': <Team.NEW_ORLEANS_PELICANS: 'NEW ORLEANS PELICANS'>,
#   'games_played': 12,
#   'games_started': 0,
#   'minutes_played': 167,
#   'made_field_goals': 12,
#   'attempted_field_goals': 47,
#   'made_three_point_field_goals': 10,
#   'attempted_three_point_field_goals': 34,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 2,
#   'defensive_rebounds': 7,
#   'assists': 10,
#   'steals': 1,
#   'blocks': 0,
#   'turnovers': 2,
#   'personal_fouls': 7,
#   'points': 34,
#   'effective_field_goal_percentage': 0.3617021276595745,
#   'total_points': 34,
#   'free_throw_percentage': 0,
#   'team_games_played': 81,
#   'wins': 33},
#  {'slug': 'bertada01',
#   'name': 'Dāvis Bertāns',
#   'positions': 2,
#   'age': 26,
#   'team': <Team.SAN_ANTONIO_SPURS: 'SAN ANTONIO SPURS'>,
#   'games_played': 76,
#   'games_started': 12,
#   'minutes_played': 1632,
#   'made_field_goals': 204,
#   'attempted_field_goals': 453,
#   'made_three_point_field_goals': 145,
#   'attempted_three_point_field_goals': 338,
#   'made_free_throws': 53,
#   'attempted_free_throws': 60,
#   'offensive_rebounds': 23,
#   'defensive_rebounds': 241,
#   'assists': 100,
#   'steals': 35,
#   'blocks': 33,
#   'turnovers': 43,
#   'personal_fouls': 133,
#   'points': 606,
#   'effective_field_goal_percentage': 0.6103752759381899,
#   'total_points': 606,
#   'free_throw_percentage': 0.8833333333333333,
#   'team_games_played': 81,
#   'wins': 47},
#  {'slug': 'beverpa01',
#   'name': 'Patrick Beverley',
#   'positions': 3,
#   'age': 30,
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'games_played': 78,
#   'games_started': 49,
#   'minutes_played': 2137,
#   'made_field_goals': 194,
#   'attempted_field_goals': 477,
#   'made_three_point_field_goals': 112,
#   'attempted_three_point_field_goals': 282,
#   'made_free_throws': 96,
#   'attempted_free_throws': 123,
#   'offensive_rebounds': 76,
#   'defensive_rebounds': 312,
#   'assists': 300,
#   'steals': 67,
#   'blocks': 43,
#   'turnovers': 85,
#   'personal_fouls': 265,
#   'points': 596,
#   'effective_field_goal_percentage': 0.5241090146750524,
#   'total_points': 596,
#   'free_throw_percentage': 0.7804878048780488,
#   'team_games_played': 81,
#   'wins': 47},
#  {'slug': 'birchkh01',
#   'name': 'Khem Birch',
#   'positions': 1,
#   'age': 26,
#   'team': <Team.ORLANDO_MAGIC: 'ORLANDO MAGIC'>,
#   'games_played': 50,
#   'games_started': 1,
#   'minutes_played': 643,
#   'made_field_goals': 91,
#   'attempted_field_goals': 151,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 58,
#   'attempted_free_throws': 83,
#   'offensive_rebounds': 79,
#   'defensive_rebounds': 111,
#   'assists': 38,
#   'steals': 18,
#   'blocks': 29,
#   'turnovers': 20,
#   'personal_fouls': 72,
#   'points': 240,
#   'effective_field_goal_percentage': 0.6026490066225165,
#   'total_points': 240,
#   'free_throw_percentage': 0.6987951807228916,
#   'team_games_played': 81,
#   'wins': 41},
#  {'slug': 'biyombi01',
#   'name': 'Bismack Biyombo',
#   'positions': 1,
#   'age': 26,
#   'team': <Team.CHARLOTTE_HORNETS: 'CHARLOTTE HORNETS'>,
#   'games_played': 54,
#   'games_started': 32,
#   'minutes_played': 783,
#   'made_field_goals': 89,
#   'attempted_field_goals': 156,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 58,
#   'attempted_free_throws': 91,
#   'offensive_rebounds': 81,
#   'defensive_rebounds': 166,
#   'assists': 33,
#   'steals': 11,
#   'blocks': 41,
#   'turnovers': 34,
#   'personal_fouls': 103,
#   'points': 236,
#   'effective_field_goal_percentage': 0.5705128205128205,
#   'total_points': 236,
#   'free_throw_percentage': 0.6373626373626373,
#   'team_games_played': 81,
#   'wins': 39},
#  {'slug': 'bjeline01',
#   'name': 'Nemanja Bjelica',
#   'positions': 2,
#   'age': 30,
#   'team': <Team.SACRAMENTO_KINGS: 'SACRAMENTO KINGS'>,
#   'games_played': 77,
#   'games_started': 70,
#   'minutes_played': 1788,
#   'made_field_goals': 284,
#   'attempted_field_goals': 593,
#   'made_three_point_field_goals': 103,
#   'attempted_three_point_field_goals': 257,
#   'made_free_throws': 70,
#   'attempted_free_throws': 92,
#   'offensive_rebounds': 125,
#   'defensive_rebounds': 319,
#   'assists': 147,
#   'steals': 54,
#   'blocks': 56,
#   'turnovers': 82,
#   'personal_fouls': 197,
#   'points': 741,
#   'effective_field_goal_percentage': 0.5657672849915683,
#   'total_points': 741,
#   'free_throw_percentage': 0.7608695652173914,
#   'team_games_played': 81,
#   'wins': 39},
#  {'slug': 'blakean01',
#   'name': 'Antonio Blakeney',
#   'positions': 3,
#   'age': 22,
#   'team': <Team.CHICAGO_BULLS: 'CHICAGO BULLS'>,
#   'games_played': 57,
#   'games_started': 3,
#   'minutes_played': 829,
#   'made_field_goals': 166,
#   'attempted_field_goals': 396,
#   'made_three_point_field_goals': 36,
#   'attempted_three_point_field_goals': 91,
#   'made_free_throws': 50,
#   'attempted_free_throws': 76,
#   'offensive_rebounds': 7,
#   'defensive_rebounds': 99,
#   'assists': 42,
#   'steals': 12,
#   'blocks': 9,
#   'turnovers': 35,
#   'personal_fouls': 41,
#   'points': 418,
#   'effective_field_goal_percentage': 0.46464646464646464,
#   'total_points': 418,
#   'free_throw_percentage': 0.6578947368421053,
#   'team_games_played': 80,
#   'wins': 22},
#  {'slug': 'bledser01',
#   'name': 'Eric Bledsoe',
#   'positions': 3,
#   'age': 29,
#   'team': <Team.MILWAUKEE_BUCKS: 'MILWAUKEE BUCKS'>,
#   'games_played': 78,
#   'games_started': 78,
#   'minutes_played': 2272,
#   'made_field_goals': 470,
#   'attempted_field_goals': 971,
#   'made_three_point_field_goals': 124,
#   'attempted_three_point_field_goals': 377,
#   'made_free_throws': 177,
#   'attempted_free_throws': 236,
#   'offensive_rebounds': 82,
#   'defensive_rebounds': 280,
#   'assists': 430,
#   'steals': 116,
#   'blocks': 29,
#   'turnovers': 165,
#   'personal_fouls': 156,
#   'points': 1241,
#   'effective_field_goal_percentage': 0.5478887744593203,
#   'total_points': 1241,
#   'free_throw_percentage': 0.75,
#   'team_games_played': 81,
#   'wins': 60},
#  {'slug': 'blossja01',
#   'name': 'Jaron Blossomgame',
#   'positions': 2,
#   'age': 25,
#   'team': <Team.CLEVELAND_CAVALIERS: 'CLEVELAND CAVALIERS'>,
#   'games_played': 27,
#   'games_started': 4,
#   'minutes_played': 439,
#   'made_field_goals': 47,
#   'attempted_field_goals': 106,
#   'made_three_point_field_goals': 10,
#   'attempted_three_point_field_goals': 39,
#   'made_free_throws': 10,
#   'attempted_free_throws': 13,
#   'offensive_rebounds': 26,
#   'defensive_rebounds': 72,
#   'assists': 13,
#   'steals': 7,
#   'blocks': 8,
#   'turnovers': 11,
#   'personal_fouls': 20,
#   'points': 114,
#   'effective_field_goal_percentage': 0.49056603773584906,
#   'total_points': 114,
#   'free_throw_percentage': 0.7692307692307693,
#   'team_games_played': 82,
#   'wins': 19},
#  {'slug': 'bogdabo01',
#   'name': 'Bogdan Bogdanović',
#   'positions': 3,
#   'age': 26,
#   'team': <Team.SACRAMENTO_KINGS: 'SACRAMENTO KINGS'>,
#   'games_played': 70,
#   'games_started': 17,
#   'minutes_played': 1947,
#   'made_field_goals': 361,
#   'attempted_field_goals': 863,
#   'made_three_point_field_goals': 134,
#   'attempted_three_point_field_goals': 372,
#   'made_free_throws': 134,
#   'attempted_free_throws': 162,
#   'offensive_rebounds': 40,
#   'defensive_rebounds': 203,
#   'assists': 267,
#   'steals': 72,
#   'blocks': 15,
#   'turnovers': 117,
#   'personal_fouls': 142,
#   'points': 990,
#   'effective_field_goal_percentage': 0.4959443800695249,
#   'total_points': 990,
#   'free_throw_percentage': 0.8271604938271605,
#   'team_games_played': 81,
#   'wins': 39},
#  {'slug': 'bogdabo02',
#   'name': 'Bojan Bogdanović',
#   'positions': 2,
#   'age': 29,
#   'team': <Team.INDIANA_PACERS: 'INDIANA PACERS'>,
#   'games_played': 81,
#   'games_started': 81,
#   'minutes_played': 2573,
#   'made_field_goals': 522,
#   'attempted_field_goals': 1051,
#   'made_three_point_field_goals': 164,
#   'attempted_three_point_field_goals': 386,
#   'made_free_throws': 246,
#   'attempted_free_throws': 305,
#   'offensive_rebounds': 33,
#   'defensive_rebounds': 300,
#   'assists': 161,
#   'steals': 69,
#   'blocks': 1,
#   'turnovers': 134,
#   'personal_fouls': 138,
#   'points': 1454,
#   'effective_field_goal_percentage': 0.5746907706945766,
#   'total_points': 1454,
#   'free_throw_percentage': 0.8065573770491803,
#   'team_games_played': 81,
#   'wins': 47},
#  {'slug': 'bogutan01',
#   'name': 'Andrew Bogut',
#   'positions': 1,
#   'age': 34,
#   'team': <Team.GOLDEN_STATE_WARRIORS: 'GOLDEN STATE WARRIORS'>,
#   'games_played': 11,
#   'games_started': 5,
#   'minutes_played': 134,
#   'made_field_goals': 18,
#   'attempted_field_goals': 36,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 3,
#   'attempted_free_throws': 3,
#   'offensive_rebounds': 12,
#   'defensive_rebounds': 43,
#   'assists': 11,
#   'steals': 3,
#   'blocks': 8,
#   'turnovers': 8,
#   'personal_fouls': 22,
#   'points': 39,
#   'effective_field_goal_percentage': 0.5,
#   'total_points': 39,
#   'free_throw_percentage': 1.0,
#   'team_games_played': 80,
#   'wins': 56},
#  {'slug': 'boldejo01',
#   'name': 'Jonah Bolden',
#   'positions': 2,
#   'age': 23,
#   'team': <Team.PHILADELPHIA_76ERS: 'PHILADELPHIA 76ERS'>,
#   'games_played': 44,
#   'games_started': 10,
#   'minutes_played': 639,
#   'made_field_goals': 80,
#   'attempted_field_goals': 162,
#   'made_three_point_field_goals': 34,
#   'attempted_three_point_field_goals': 96,
#   'made_free_throws': 13,
#   'attempted_free_throws': 27,
#   'offensive_rebounds': 47,
#   'defensive_rebounds': 118,
#   'assists': 40,
#   'steals': 17,
#   'blocks': 39,
#   'turnovers': 36,
#   'personal_fouls': 99,
#   'points': 207,
#   'effective_field_goal_percentage': 0.5987654320987654,
#   'total_points': 207,
#   'free_throw_percentage': 0.48148148148148145,
#   'team_games_played': 80,
#   'wins': 50},
#  {'slug': 'bongais01',
#   'name': 'Isaac Bonga',
#   'positions': 3,
#   'age': 19,
#   'team': <Team.LOS_ANGELES_LAKERS: 'LOS ANGELES LAKERS'>,
#   'games_played': 22,
#   'games_started': 0,
#   'minutes_played': 120,
#   'made_field_goals': 5,
#   'attempted_field_goals': 33,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 8,
#   'made_free_throws': 9,
#   'attempted_free_throws': 15,
#   'offensive_rebounds': 9,
#   'defensive_rebounds': 16,
#   'assists': 15,
#   'steals': 9,
#   'blocks': 4,
#   'turnovers': 6,
#   'personal_fouls': 9,
#   'points': 19,
#   'effective_field_goal_percentage': 0.15151515151515152,
#   'total_points': 19,
#   'free_throw_percentage': 0.6,
#   'team_games_played': 81,
#   'wins': 37},
#  {'slug': 'bookede01',
#   'name': 'Devin Booker',
#   'positions': 3,
#   'age': 22,
#   'team': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'games_played': 64,
#   'games_started': 64,
#   'minutes_played': 2242,
#   'made_field_goals': 586,
#   'attempted_field_goals': 1255,
#   'made_three_point_field_goals': 135,
#   'attempted_three_point_field_goals': 414,
#   'made_free_throws': 393,
#   'attempted_free_throws': 454,
#   'offensive_rebounds': 39,
#   'defensive_rebounds': 226,
#   'assists': 433,
#   'steals': 56,
#   'blocks': 13,
#   'turnovers': 264,
#   'personal_fouls': 200,
#   'points': 1700,
#   'effective_field_goal_percentage': 0.5207171314741036,
#   'total_points': 1700,
#   'free_throw_percentage': 0.8656387665198237,
#   'team_games_played': 81,
#   'wins': 19},
#  {'slug': 'bouchch01',
#   'name': 'Chris Boucher',
#   'positions': 2,
#   'age': 26,
#   'team': <Team.TORONTO_RAPTORS: 'TORONTO RAPTORS'>,
#   'games_played': 28,
#   'games_started': 0,
#   'minutes_played': 163,
#   'made_field_goals': 34,
#   'attempted_field_goals': 76,
#   'made_three_point_field_goals': 12,
#   'attempted_three_point_field_goals': 37,
#   'made_free_throws': 13,
#   'attempted_free_throws': 15,
#   'offensive_rebounds': 16,
#   'defensive_rebounds': 40,
#   'assists': 2,
#   'steals': 6,
#   'blocks': 24,
#   'turnovers': 7,
#   'personal_fouls': 31,
#   'points': 93,
#   'effective_field_goal_percentage': 0.5263157894736842,
#   'total_points': 93,
#   'free_throw_percentage': 0.8666666666666667,
#   'team_games_played': 81,
#   'wins': 57},
#  {'slug': 'bradlto01',
#   'name': 'Tony Bradley',
#   'positions': 1,
#   'age': 21,
#   'team': <Team.UTAH_JAZZ: 'UTAH JAZZ'>,
#   'games_played': 3,
#   'games_started': 0,
#   'minutes_played': 36,
#   'made_field_goals': 8,
#   'attempted_field_goals': 16,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 1,
#   'attempted_free_throws': 2,
#   'offensive_rebounds': 9,
#   'defensive_rebounds': 6,
#   'assists': 1,
#   'steals': 2,
#   'blocks': 2,
#   'turnovers': 3,
#   'personal_fouls': 6,
#   'points': 17,
#   'effective_field_goal_percentage': 0.5,
#   'total_points': 17,
#   'free_throw_percentage': 0.5,
#   'team_games_played': 80,
#   'wins': 49},
#  {'slug': 'bridgmi01',
#   'name': 'Mikal Bridges',
#   'positions': 2,
#   'age': 22,
#   'team': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'games_played': 82,
#   'games_started': 56,
#   'minutes_played': 2417,
#   'made_field_goals': 242,
#   'attempted_field_goals': 563,
#   'made_three_point_field_goals': 105,
#   'attempted_three_point_field_goals': 313,
#   'made_free_throws': 95,
#   'attempted_free_throws': 118,
#   'offensive_rebounds': 56,
#   'defensive_rebounds': 208,
#   'assists': 173,
#   'steals': 129,
#   'blocks': 38,
#   'turnovers': 70,
#   'personal_fouls': 201,
#   'points': 684,
#   'effective_field_goal_percentage': 0.5230905861456483,
#   'total_points': 684,
#   'free_throw_percentage': 0.8050847457627118,
#   'team_games_played': 81,
#   'wins': 19},
#  {'slug': 'bridgmi02',
#   'name': 'Miles Bridges',
#   'positions': 2,
#   'age': 20,
#   'team': <Team.CHARLOTTE_HORNETS: 'CHARLOTTE HORNETS'>,
#   'games_played': 80,
#   'games_started': 25,
#   'minutes_played': 1696,
#   'made_field_goals': 237,
#   'attempted_field_goals': 511,
#   'made_three_point_field_goals': 65,
#   'attempted_three_point_field_goals': 200,
#   'made_free_throws': 58,
#   'attempted_free_throws': 77,
#   'offensive_rebounds': 67,
#   'defensive_rebounds': 256,
#   'assists': 95,
#   'steals': 55,
#   'blocks': 49,
#   'turnovers': 50,
#   'personal_fouls': 111,
#   'points': 597,
#   'effective_field_goal_percentage': 0.5273972602739726,
#   'total_points': 597,
#   'free_throw_percentage': 0.7532467532467533,
#   'team_games_played': 81,
#   'wins': 39},
#  {'slug': 'briscis01',
#   'name': 'Isaiah Briscoe',
#   'positions': 3,
#   'age': 22,
#   'team': <Team.ORLANDO_MAGIC: 'ORLANDO MAGIC'>,
#   'games_played': 39,
#   'games_started': 0,
#   'minutes_played': 559,
#   'made_field_goals': 55,
#   'attempted_field_goals': 138,
#   'made_three_point_field_goals': 11,
#   'attempted_three_point_field_goals': 34,
#   'made_free_throws': 15,
#   'attempted_free_throws': 26,
#   'offensive_rebounds': 5,
#   'defensive_rebounds': 69,
#   'assists': 87,
#   'steals': 11,
#   'blocks': 2,
#   'turnovers': 31,
#   'personal_fouls': 66,
#   'points': 136,
#   'effective_field_goal_percentage': 0.4384057971014493,
#   'total_points': 136,
#   'free_throw_percentage': 0.5769230769230769,
#   'team_games_played': 81,
#   'wins': 41},
#  {'slug': 'broekry01',
#   'name': 'Ryan Broekhoff',
#   'positions': 3,
#   'age': 28,
#   'team': <Team.DALLAS_MAVERICKS: 'DALLAS MAVERICKS'>,
#   'games_played': 42,
#   'games_started': 0,
#   'minutes_played': 453,
#   'made_field_goals': 57,
#   'attempted_field_goals': 126,
#   'made_three_point_field_goals': 38,
#   'attempted_three_point_field_goals': 93,
#   'made_free_throws': 15,
#   'attempted_free_throws': 19,
#   'offensive_rebounds': 8,
#   'defensive_rebounds': 55,
#   'assists': 22,
#   'steals': 6,
#   'blocks': 4,
#   'turnovers': 16,
#   'personal_fouls': 35,
#   'points': 167,
#   'effective_field_goal_percentage': 0.6031746031746031,
#   'total_points': 167,
#   'free_throw_percentage': 0.7894736842105263,
#   'team_games_played': 80,
#   'wins': 32},
#  {'slug': 'brogdma01',
#   'name': 'Malcolm Brogdon',
#   'positions': 3,
#   'age': 26,
#   'team': <Team.MILWAUKEE_BUCKS: 'MILWAUKEE BUCKS'>,
#   'games_played': 64,
#   'games_started': 64,
#   'minutes_played': 1832,
#   'made_field_goals': 378,
#   'attempted_field_goals': 748,
#   'made_three_point_field_goals': 104,
#   'attempted_three_point_field_goals': 244,
#   'made_free_throws': 141,
#   'attempted_free_throws': 152,
#   'offensive_rebounds': 65,
#   'defensive_rebounds': 223,
#   'assists': 205,
#   'steals': 46,
#   'blocks': 13,
#   'turnovers': 91,
#   'personal_fouls': 102,
#   'points': 1001,
#   'effective_field_goal_percentage': 0.5748663101604278,
#   'total_points': 1001,
#   'free_throw_percentage': 0.9276315789473685,
#   'team_games_played': 81,
#   'wins': 60},
#  {'slug': 'brookdi01',
#   'name': 'Dillon Brooks',
#   'positions': 2,
#   'age': 23,
#   'team': <Team.MEMPHIS_GRIZZLIES: 'MEMPHIS GRIZZLIES'>,
#   'games_played': 18,
#   'games_started': 0,
#   'minutes_played': 330,
#   'made_field_goals': 49,
#   'attempted_field_goals': 122,
#   'made_three_point_field_goals': 15,
#   'attempted_three_point_field_goals': 40,
#   'made_free_throws': 22,
#   'attempted_free_throws': 30,
#   'offensive_rebounds': 9,
#   'defensive_rebounds': 22,
#   'assists': 16,
#   'steals': 10,
#   'blocks': 4,
#   'turnovers': 19,
#   'personal_fouls': 50,
#   'points': 135,
#   'effective_field_goal_percentage': 0.46311475409836067,
#   'total_points': 135,
#   'free_throw_percentage': 0.7333333333333333,
#   'team_games_played': 80,
#   'wins': 32},
#  {'slug': 'brookma01',
#   'name': 'MarShon Brooks',
#   'positions': 3,
#   'age': 30,
#   'team': <Team.MEMPHIS_GRIZZLIES: 'MEMPHIS GRIZZLIES'>,
#   'games_played': 29,
#   'games_started': 0,
#   'minutes_played': 387,
#   'made_field_goals': 76,
#   'attempted_field_goals': 169,
#   'made_three_point_field_goals': 15,
#   'attempted_three_point_field_goals': 54,
#   'made_free_throws': 23,
#   'attempted_free_throws': 33,
# ...
#   'turnovers': 151,
#   'personal_fouls': 145,
#   'effective_field_goal_percentage': 0.5333778371161548,
#   'total_points': 930,
#   'free_throw_percentage': 0.7119565217391305,
#   'team_games_played': 80,
#   'wins': 22},
#  {'slug': 'payneca01',
#   'name': 'Cameron Payne',
#   'positions': 3,
#   'age': 24,
#   'team': <Team.CHICAGO_BULLS: 'CHICAGO BULLS'>,
#   'games_played': 40,
#   'games_started': 13,
#   'minutes_played': 712,
#   'made_field_goals': 96,
#   'attempted_field_goals': 223,
#   'made_three_point_field_goals': 25,
#   'attempted_three_point_field_goals': 84,
#   'made_free_throws': 33,
#   'attempted_free_throws': 41,
#   'offensive_rebounds': 13,
#   'defensive_rebounds': 59,
#   'assists': 106,
#   'steals': 28,
#   'blocks': 9,
#   'turnovers': 45,
#   'personal_fouls': 64,
#   'effective_field_goal_percentage': 0.48654708520179374,
#   'total_points': 250,
#   'free_throw_percentage': 0.8048780487804879,
#   'team_games_played': 80,
#   'wins': 22},
#  {'slug': 'porteot01',
#   'name': 'Otto Porter',
#   'positions': 2,
#   'age': 25,
#   'team': <Team.WASHINGTON_WIZARDS: 'WASHINGTON WIZARDS'>,
#   'games_played': 56,
#   'games_started': 43,
#   'minutes_played': 1683,
#   'made_field_goals': 299,
#   'attempted_field_goals': 643,
#   'made_three_point_field_goals': 104,
#   'attempted_three_point_field_goals': 256,
#   'made_free_throws': 78,
#   'attempted_free_throws': 96,
#   'offensive_rebounds': 54,
#   'defensive_rebounds': 260,
#   'assists': 120,
#   'steals': 82,
#   'blocks': 31,
#   'turnovers': 65,
#   'personal_fouls': 108,
#   'effective_field_goal_percentage': 0.5458786936236392,
#   'total_points': 780,
#   'free_throw_percentage': 0.8125,
#   'team_games_played': 81,
#   'wins': 32},
#  {'slug': 'portibo01',
#   'name': 'Bobby Portis',
#   'positions': 2,
#   'age': 23,
#   'team': <Team.CHICAGO_BULLS: 'CHICAGO BULLS'>,
#   'games_played': 50,
#   'games_started': 28,
#   'minutes_played': 1299,
#   'made_field_goals': 279,
#   'attempted_field_goals': 628,
#   'made_three_point_field_goals': 75,
#   'attempted_three_point_field_goals': 191,
#   'made_free_throws': 77,
#   'attempted_free_throws': 97,
#   'offensive_rebounds': 109,
#   'defensive_rebounds': 294,
#   'assists': 72,
#   'steals': 35,
#   'blocks': 20,
#   'turnovers': 74,
#   'personal_fouls': 145,
#   'effective_field_goal_percentage': 0.5039808917197452,
#   'total_points': 710,
#   'free_throw_percentage': 0.7938144329896907,
#   'team_games_played': 80,
#   'wins': 22},
#  {'slug': 'riverau01',
#   'name': 'Austin Rivers',
#   'positions': 3,
#   'age': 26,
#   'team': <Team.WASHINGTON_WIZARDS: 'WASHINGTON WIZARDS'>,
#   'games_played': 76,
#   'games_started': 15,
#   'minutes_played': 2028,
#   'made_field_goals': 232,
#   'attempted_field_goals': 572,
#   'made_three_point_field_goals': 104,
#   'attempted_three_point_field_goals': 327,
#   'made_free_throws': 50,
#   'attempted_free_throws': 95,
#   'offensive_rebounds': 25,
#   'defensive_rebounds': 137,
#   'assists': 167,
#   'steals': 47,
#   'blocks': 23,
#   'turnovers': 68,
#   'personal_fouls': 207,
#   'effective_field_goal_percentage': 0.4965034965034965,
#   'total_points': 618,
#   'free_throw_percentage': 0.5263157894736842,
#   'team_games_played': 81,
#   'wins': 32},
#  {'slug': 'saricda01',
#   'name': 'Dario Šarić',
#   'positions': 2,
#   'age': 24,
#   'team': <Team.PHILADELPHIA_76ERS: 'PHILADELPHIA 76ERS'>,
#   'games_played': 81,
#   'games_started': 41,
#   'minutes_played': 2023,
#   'made_field_goals': 304,
#   'attempted_field_goals': 696,
#   'made_three_point_field_goals': 118,
#   'attempted_three_point_field_goals': 323,
#   'made_free_throws': 132,
#   'attempted_free_throws': 150,
#   'offensive_rebounds': 126,
#   'defensive_rebounds': 331,
#   'assists': 127,
#   'steals': 45,
#   'blocks': 9,
#   'turnovers': 97,
#   'personal_fouls': 182,
#   'effective_field_goal_percentage': 0.521551724137931,
#   'total_points': 858,
#   'free_throw_percentage': 0.88,
#   'team_games_played': 80,
#   'wins': 50},
#  {'slug': 'scottmi01',
#   'name': 'Mike Scott',
#   'positions': 2,
#   'age': 30,
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'games_played': 79,
#   'games_started': 3,
#   'minutes_played': 1395,
#   'made_field_goals': 168,
#   'attempted_field_goals': 420,
#   'made_three_point_field_goals': 101,
#   'attempted_three_point_field_goals': 252,
#   'made_free_throws': 22,
#   'attempted_free_throws': 33,
#   'offensive_rebounds': 43,
#   'defensive_rebounds': 233,
#   'assists': 66,
#   'steals': 26,
#   'blocks': 13,
#   'turnovers': 44,
#   'personal_fouls': 156,
#   'effective_field_goal_percentage': 0.5202380952380953,
#   'total_points': 459,
#   'free_throw_percentage': 0.6666666666666666,
#   'team_games_played': 81,
#   'wins': 47},
#  {'slug': 'seldewa01',
#   'name': 'Wayne Selden',
#   'positions': 3,
#   'age': 24,
#   'team': <Team.MEMPHIS_GRIZZLIES: 'MEMPHIS GRIZZLIES'>,
#   'games_played': 75,
#   'games_started': 13,
#   'minutes_played': 1439,
#   'made_field_goals': 196,
#   'attempted_field_goals': 483,
#   'made_three_point_field_goals': 55,
#   'attempted_three_point_field_goals': 174,
#   'made_free_throws': 67,
#   'attempted_free_throws': 92,
#   'offensive_rebounds': 37,
#   'defensive_rebounds': 143,
#   'assists': 109,
#   'steals': 33,
#   'blocks': 13,
#   'turnovers': 79,
#   'personal_fouls': 131,
#   'effective_field_goal_percentage': 0.46273291925465837,
#   'total_points': 514,
#   'free_throw_percentage': 0.7282608695652174,
#   'team_games_played': 80,
#   'wins': 32},
#  {'slug': 'shamela01',
#   'name': 'Landry Shamet',
#   'positions': 3,
#   'age': 21,
#   'team': <Team.PHILADELPHIA_76ERS: 'PHILADELPHIA 76ERS'>,
#   'games_played': 79,
#   'games_started': 27,
#   'minutes_played': 1802,
#   'made_field_goals': 240,
#   'attempted_field_goals': 557,
#   'made_three_point_field_goals': 167,
#   'attempted_three_point_field_goals': 396,
#   'made_free_throws': 75,
#   'attempted_free_throws': 93,
#   'offensive_rebounds': 21,
#   'defensive_rebounds': 113,
#   'assists': 117,
#   'steals': 37,
#   'blocks': 10,
#   'turnovers': 45,
#   'personal_fouls': 155,
#   'effective_field_goal_percentage': 0.5807899461400359,
#   'total_points': 722,
#   'free_throw_percentage': 0.8064516129032258,
#   'team_games_played': 80,
#   'wins': 50},
#  {'slug': 'shumpim01',
#   'name': 'Iman Shumpert',
#   'positions': 3,
#   'age': 28,
#   'team': <Team.SACRAMENTO_KINGS: 'SACRAMENTO KINGS'>,
#   'games_played': 62,
#   'games_started': 41,
#   'minutes_played': 1481,
#   'made_field_goals': 167,
#   'attempted_field_goals': 446,
#   'made_three_point_field_goals': 95,
#   'attempted_three_point_field_goals': 273,
#   'made_free_throws': 36,
#   'attempted_free_throws': 45,
#   'offensive_rebounds': 27,
#   'defensive_rebounds': 156,
#   'assists': 112,
#   'steals': 59,
#   'blocks': 24,
#   'turnovers': 50,
#   'personal_fouls': 127,
#   'effective_field_goal_percentage': 0.48094170403587444,
#   'total_points': 465,
#   'free_throw_percentage': 0.8,
#   'team_games_played': 81,
#   'wins': 39},
#  {'slug': 'simmojo02',
#   'name': 'Jonathon Simmons',
#   'positions': 3,
#   'age': 29,
#   'team': <Team.ORLANDO_MAGIC: 'ORLANDO MAGIC'>,
#   'games_played': 56,
#   'games_started': 9,
#   'minutes_played': 1064,
#   'made_field_goals': 133,
#   'attempted_field_goals': 350,
#   'made_three_point_field_goals': 28,
#   'attempted_three_point_field_goals': 104,
#   'made_free_throws': 72,
#   'attempted_free_throws': 97,
#   'offensive_rebounds': 27,
#   'defensive_rebounds': 99,
#   'assists': 128,
#   'steals': 29,
#   'blocks': 15,
#   'turnovers': 68,
#   'personal_fouls': 89,
#   'effective_field_goal_percentage': 0.42,
#   'total_points': 366,
#   'free_throw_percentage': 0.7422680412371134,
#   'team_games_played': 81,
#   'wins': 41},
#  {'slug': 'smithde03',
#   'name': 'Dennis Smith Jr.',
#   'positions': 3,
#   'age': 21,
#   'team': <Team.DALLAS_MAVERICKS: 'DALLAS MAVERICKS'>,
#   'games_played': 53,
#   'games_started': 50,
#   'minutes_played': 1508,
#   'made_field_goals': 278,
#   'attempted_field_goals': 650,
#   'made_three_point_field_goals': 67,
#   'attempted_three_point_field_goals': 208,
#   'made_free_throws': 99,
#   'attempted_free_throws': 156,
#   'offensive_rebounds': 32,
#   'defensive_rebounds': 123,
#   'assists': 252,
#   'steals': 67,
#   'blocks': 20,
#   'turnovers': 154,
#   'personal_fouls': 129,
#   'effective_field_goal_percentage': 0.47923076923076924,
#   'total_points': 722,
#   'free_throw_percentage': 0.6346153846153846,
#   'team_games_played': 80,
#   'wins': 32},
#  {'slug': 'smithja02',
#   'name': 'Jason Smith',
#   'positions': 1,
#   'age': 32,
#   'team': <Team.WASHINGTON_WIZARDS: 'WASHINGTON WIZARDS'>,
#   'games_played': 20,
#   'games_started': 1,
#   'minutes_played': 190,
#   'made_field_goals': 21,
#   'attempted_field_goals': 59,
#   'made_three_point_field_goals': 9,
#   'attempted_three_point_field_goals': 26,
#   'made_free_throws': 14,
#   'attempted_free_throws': 16,
#   'offensive_rebounds': 16,
#   'defensive_rebounds': 36,
#   'assists': 14,
#   'steals': 3,
#   'blocks': 7,
#   'turnovers': 13,
#   'personal_fouls': 30,
#   'effective_field_goal_percentage': 0.4322033898305085,
#   'total_points': 65,
#   'free_throw_percentage': 0.875,
#   'team_games_played': 81,
#   'wins': 32},
#  {'slug': 'spaldra01',
#   'name': 'Ray Spalding',
#   'positions': 2,
#   'age': 21,
#   'team': <Team.DALLAS_MAVERICKS: 'DALLAS MAVERICKS'>,
#   'games_played': 14,
#   'games_started': 3,
#   'minutes_played': 148,
#   'made_field_goals': 25,
#   'attempted_field_goals': 47,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 3,
#   'made_free_throws': 4,
#   'attempted_free_throws': 12,
#   'offensive_rebounds': 15,
#   'defensive_rebounds': 33,
#   'assists': 5,
#   'steals': 9,
#   'blocks': 8,
#   'turnovers': 9,
#   'personal_fouls': 23,
#   'effective_field_goal_percentage': 0.5319148936170213,
#   'total_points': 54,
#   'free_throw_percentage': 0.3333333333333333,
#   'team_games_played': 80,
#   'wins': 32},
#  {'slug': 'stausni01',
#   'name': 'Nik Stauskas',
#   'positions': 3,
#   'age': 25,
#   'team': <Team.PORTLAND_TRAIL_BLAZERS: 'PORTLAND TRAIL BLAZERS'>,
#   'games_played': 68,
#   'games_started': 0,
#   'minutes_played': 1015,
#   'made_field_goals': 136,
#   'attempted_field_goals': 338,
#   'made_three_point_field_goals': 70,
#   'attempted_three_point_field_goals': 188,
#   'made_free_throws': 57,
#   'attempted_free_throws': 64,
#   'offensive_rebounds': 18,
#   'defensive_rebounds': 109,
#   'assists': 81,
#   'steals': 21,
#   'blocks': 7,
#   'turnovers': 51,
#   'personal_fouls': 50,
#   'effective_field_goal_percentage': 0.5059171597633136,
#   'total_points': 399,
#   'free_throw_percentage': 0.890625,
#   'team_games_played': 80,
#   'wins': 51},
#  {'slug': 'swanica01',
#   'name': 'Caleb Swanigan',
#   'positions': 2,
#   'age': 21,
#   'team': <Team.PORTLAND_TRAIL_BLAZERS: 'PORTLAND TRAIL BLAZERS'>,
#   'games_played': 21,
#   'games_started': 0,
#   'minutes_played': 178,
#   'made_field_goals': 18,
#   'attempted_field_goals': 53,
#   'made_three_point_field_goals': 1,
#   'attempted_three_point_field_goals': 7,
#   'made_free_throws': 6,
#   'attempted_free_throws': 9,
#   'offensive_rebounds': 17,
#   'defensive_rebounds': 47,
#   'assists': 11,
#   'steals': 6,
#   'blocks': 1,
#   'turnovers': 18,
#   'personal_fouls': 28,
#   'effective_field_goal_percentage': 0.3490566037735849,
#   'total_points': 43,
#   'free_throw_percentage': 0.6666666666666666,
#   'team_games_played': 80,
#   'wins': 51},
#  {'slug': 'templga01',
#   'name': 'Garrett Temple',
#   'positions': 3,
#   'age': 32,
#   'team': <Team.MEMPHIS_GRIZZLIES: 'MEMPHIS GRIZZLIES'>,
#   'games_played': 75,
#   'games_started': 55,
#   'minutes_played': 2040,
#   'made_field_goals': 208,
#   'attempted_field_goals': 493,
#   'made_three_point_field_goals': 90,
#   'attempted_three_point_field_goals': 264,
#   'made_free_throws': 80,
#   'attempted_free_throws': 107,
#   'offensive_rebounds': 28,
#   'defensive_rebounds': 188,
#   'assists': 106,
#   'steals': 76,
#   'blocks': 30,
#   'turnovers': 70,
#   'personal_fouls': 204,
#   'effective_field_goal_percentage': 0.513184584178499,
#   'total_points': 586,
#   'free_throw_percentage': 0.7476635514018691,
#   'team_games_played': 80,
#   'wins': 32},
#  {'slug': 'terryem01',
#   'name': 'Emanuel Terry',
#   'positions': 2,
#   'age': 22,
#   'team': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'games_played': 3,
#   'games_started': 0,
#   'minutes_played': 23,
#   'made_field_goals': 4,
#   'attempted_field_goals': 7,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 2,
#   'attempted_free_throws': 4,
#   'offensive_rebounds': 3,
#   'defensive_rebounds': 4,
#   'assists': 2,
#   'steals': 3,
#   'blocks': 0,
#   'turnovers': 2,
#   'personal_fouls': 4,
#   'effective_field_goal_percentage': 0.5714285714285714,
#   'total_points': 10,
#   'free_throw_percentage': 0.5,
#   'team_games_played': 81,
#   'wins': 19},
#  {'slug': 'valanjo01',
#   'name': 'Jonas Valančiūnas',
#   'positions': 1,
#   'age': 26,
#   'team': <Team.TORONTO_RAPTORS: 'TORONTO RAPTORS'>,
#   'games_played': 49,
#   'games_started': 27,
#   'minutes_played': 1091,
#   'made_field_goals': 301,
#   'attempted_field_goals': 538,
#   'made_three_point_field_goals': 14,
#   'attempted_three_point_field_goals': 48,
#   'made_free_throws': 147,
#   'attempted_free_throws': 185,
#   'offensive_rebounds': 106,
#   'defensive_rebounds': 313,
#   'assists': 70,
#   'steals': 19,
#   'blocks': 53,
#   'turnovers': 90,
#   'personal_fouls': 146,
#   'effective_field_goal_percentage': 0.5724907063197026,
#   'total_points': 763,
#   'free_throw_percentage': 0.7945945945945946,
#   'team_games_played': 81,
#   'wins': 57},
#  {'slug': 'woodch01',
#   'name': 'Christian Wood',
#   'positions': 2,
#   'age': 23,
#   'team': <Team.MILWAUKEE_BUCKS: 'MILWAUKEE BUCKS'>,
#   'games_played': 21,
#   'games_started': 2,
#   'minutes_played': 251,
#   'made_field_goals': 61,
#   'attempted_field_goals': 117,
#   'made_three_point_field_goals': 9,
#   'attempted_three_point_field_goals': 26,
#   'made_free_throws': 41,
#   'attempted_free_throws': 56,
#   'offensive_rebounds': 17,
#   'defensive_rebounds': 66,
#   'assists': 8,
#   'steals': 7,
#   'blocks': 10,
#   'turnovers': 17,
#   'personal_fouls': 17,
#   'effective_field_goal_percentage': 0.5598290598290598,
#   'total_points': 172,
#   'free_throw_percentage': 0.7321428571428571,
#   'team_games_played': 81,
#   'wins': 60},
#  {'slug': 'wrighde01',
#   'name': 'Delon Wright',
#   'positions': 3,
#   'age': 26,
#   'team': <Team.TORONTO_RAPTORS: 'TORONTO RAPTORS'>,
#   'games_played': 75,
#   'games_started': 13,
#   'minutes_played': 1699,
#   'made_field_goals': 242,
#   'attempted_field_goals': 558,
#   'made_three_point_field_goals': 50,
#   'attempted_three_point_field_goals': 168,
#   'made_free_throws': 119,
#   'attempted_free_throws': 150,
#   'offensive_rebounds': 68,
#   'defensive_rebounds': 198,
#   'assists': 248,
#   'steals': 88,
#   'blocks': 30,
#   'turnovers': 77,
#   'personal_fouls': 103,
#   'effective_field_goal_percentage': 0.478494623655914,
#   'total_points': 653,
#   'free_throw_percentage': 0.7933333333333333,
#   'team_games_played': 81,
#   'wins': 57},
#  {'slug': 'zellety01',
#   'name': 'Tyler Zeller',
#   'positions': 1,
#   'age': 29,
#   'team': <Team.ATLANTA_HAWKS: 'ATLANTA HAWKS'>,
#   'games_played': 6,
#   'games_started': 1,
#   'minutes_played': 93,
#   'made_field_goals': 16,
#   'attempted_field_goals': 30,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 14,
#   'attempted_free_throws': 18,
#   'offensive_rebounds': 11,
#   'defensive_rebounds': 13,
#   'assists': 4,
#   'steals': 1,
#   'blocks': 3,
#   'turnovers': 4,
#   'personal_fouls': 20,
#   'effective_field_goal_percentage': 0.5333333333333333,
#   'total_points': 46,
#   'free_throw_percentage': 0.7777777777777778,
#   'team_games_played': 81,
#   'wins': 29},
#  {'slug': 'zubaciv01',
#   'name': 'Ivica Zubac',
#   'positions': 1,
#   'age': 21,
#   'team': <Team.LOS_ANGELES_LAKERS: 'LOS ANGELES LAKERS'>,
#   'games_played': 59,
#   'games_started': 37,
#   'minutes_played': 1040,
#   'made_field_goals': 212,
#   'attempted_field_goals': 379,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 101,
#   'attempted_free_throws': 126,
#   'offensive_rebounds': 115,
#   'defensive_rebounds': 247,
#   'assists': 63,
#   'steals': 14,
#   'blocks': 51,
#   'turnovers': 70,
#   'personal_fouls': 137,
#   'effective_field_goal_percentage': 0.5593667546174143,
#   'total_points': 525,
#   'free_throw_percentage': 0.8015873015873016,
#   'team_games_played': 81,
#   'wins': 37}]

# %% [markdown]
# ### Using beautiful soup to get a nice clean list of the All-NBA players since 2000.

# %%
from bs4 import BeautifulSoup
import urllib.request
import collections
import re
import bs4
import lxml

url = 'https://www.basketball-reference.com/awards/all_league.html'

soup = BeautifulSoup()

textList = []
allNbaTeamDict = {}
with urllib.request.urlopen(url) as ef:
    soup = BeautifulSoup(ef)
    textList = soup.find('table').get_text().splitlines()[15:]

    for line in textList:
        year = line[:7]
        formattedYear = year[:2] + year[5:]
        if formattedYear == '1900':
            formattedYear = '2001'
        if year == '1999-00':
            break
        if formattedYear not in allNbaTeamDict:
            allNbaTeamDict[formattedYear] = []
        wordList = line[13:].split()
        if len(wordList) == 0:
            continue
        playerTuple = (wordList[2][0],"%s %s" % (wordList[0], wordList[1]))
        allNbaTeamDict[formattedYear].append(playerTuple)
        playerTuple = (wordList[4][0],"%s %s" % (wordList[2][1:], wordList[3]))
        allNbaTeamDict[formattedYear].append(playerTuple)
        playerTuple = (wordList[6][0],"%s %s" % (wordList[4][1:], wordList[5]))
        allNbaTeamDict[formattedYear].append(playerTuple)
        playerTuple = (wordList[8][0],"%s %s" % (wordList[6][1:], wordList[7]))
        allNbaTeamDict[formattedYear].append(playerTuple)
        playerTuple = (wordList[10][0],"%s %s" % (wordList[8][1:], wordList[9]))
        allNbaTeamDict[formattedYear].append(playerTuple)
    allNbaTeamDict.pop('')

print(allNbaTeamDict)
# Out:
# {'2019': [('C', 'Nikola Jokić'), ('F', 'Giannis Antetokounmpo'), ('F', 'Paul George'), ('G', 'James Harden'), ('G', 'Stephen Curry'), ('C', 'Joel Embiid'), ('F', 'Kevin Durant'), ('F', 'Kawhi Leonard'), ('G', 'Damian Lillard'), ('G', 'Kyrie Irving'), ('C', 'Rudy Gobert'), ('F', 'LeBron James'), ('F', 'Blake Griffin'), ('G', 'Kemba Walker'), ('G', 'Russell Westbrook')], '2018': [('C', 'Anthony Davis'), ('F', 'LeBron James'), ('F', 'Kevin Durant'), ('G', 'Damian Lillard'), ('G', 'James Harden'), ('C', 'Joel Embiid'), ('F', 'Giannis Antetokounmpo'), ('F', 'LaMarcus Aldridge'), ('G', 'Russell Westbrook'), ('G', 'DeMar DeRozan'), ('C', 'Karl-Anthony Towns'), ('F', 'Jimmy Butler'), ('F', 'Paul George'), ('G', 'Stephen Curry'), ('G', 'Victor Oladipo')], '2017': [('C', 'Anthony Davis'), ('F', 'LeBron James'), ('F', 'Kawhi Leonard'), ('G', 'James Harden'), ('G', 'Russell Westbrook'), ('C', 'Rudy Gobert'), ('F', 'Giannis Antetokounmpo'), ('F', 'Kevin Durant'), ('G', 'Stephen Curry'), ('G', 'Isaiah Thomas'), ('C', 'DeAndre Jordan'), ('F', 'Draymond Green'), ('F', 'Jimmy Butler'), ('G', 'John Wall'), ('G', 'DeMar DeRozan')], '2016': [('C', 'DeAndre Jordan'), ('F', 'LeBron James'), ('F', 'Kawhi Leonard'), ('G', 'Stephen Curry'), ('G', 'Russell Westbrook'), ('C', 'DeMarcus Cousins'), ('F', 'Kevin Durant'), ('F', 'Draymond Green'), ('G', 'Chris Paul'), ('G', 'Damian Lillard'), ('C', 'Andre Drummond'), ('F', 'Paul George'), ('F', 'LaMarcus Aldridge'), ('G', 'Klay Thompson'), ('G', 'Kyle Lowry')], '2015': [('C', 'Marc Gasol'), ('F', 'LeBron James'), ('F', 'Anthony Davis'), ('G', 'Stephen Curry'), ('G', 'James Harden'), ('C', 'DeMarcus Cousins'), ('C', 'Pau Gasol'), ('F', 'LaMarcus Aldridge'), ('G', 'Russell Westbrook'), ('G', 'Chris Paul'), ('C', 'DeAndre Jordan'), ('F', 'Blake Griffin'), ('F', 'Tim Duncan'), ('G', 'Klay Thompson'), ('G', 'Kyrie Irving')], '2014': [('C', 'Joakim Noah'), ('F', 'Kevin Durant'), ('F', 'LeBron James'), ('G', 'James Harden'), ('G', 'Chris Paul'), ('C', 'Dwight Howard'), ('F', 'Blake Griffin'), ('F', 'Kevin Love'), ('G', 'Stephen Curry'), ('G', 'Tony Parker'), ('C', 'Al Jefferson'), ('F', 'Paul George'), ('F', 'LaMarcus Aldridge'), ('G', 'Goran Dragić'), ('G', 'Damian Lillard')], '2013': [('C', 'Tim Duncan'), ('F', 'Kevin Durant'), ('F', 'LeBron James'), ('G', 'Kobe Bryant'), ('G', 'Chris Paul'), ('C', 'Marc Gasol'), ('F', 'Carmelo Anthony'), ('F', 'Blake Griffin'), ('G', 'Tony Parker'), ('G', 'Russell Westbrook'), ('C', 'Dwight Howard'), ('F', 'Paul George'), ('F', 'David Lee'), ('G', 'James Harden'), ('G', 'Dwyane Wade')], '2012': [('C', 'Dwight Howard'), ('F', 'Kevin Durant'), ('F', 'LeBron James'), ('G', 'Kobe Bryant'), ('G', 'Chris Paul'), ('C', 'Andrew Bynum'), ('F', 'Blake Griffin'), ('F', 'Kevin Love'), ('G', 'Tony Parker'), ('G', 'Russell Westbrook'), ('C', 'Tyson Chandler'), ('F', 'Carmelo Anthony'), ('F', 'Dirk Nowitzki'), ('G', 'Rajon Rondo'), ('G', 'Dwyane Wade')], '2011': [('C', 'Dwight Howard'), ('F', 'Kevin Durant'), ('F', 'LeBron James'), ('G', 'Kobe Bryant'), ('G', 'Derrick Rose'), ('C', "Amar'e Stoudemire"), ('F', 'Pau Gasol'), ('F', 'Dirk Nowitzki'), ('G', 'Dwyane Wade'), ('G', 'Russell Westbrook'), ('C', 'Al Horford'), ('F', 'LaMarcus Aldridge'), ('F', 'Zach Randolph'), ('G', 'Manu Ginóbili'), ('G', 'Chris Paul')], '2010': [('C', 'Dwight Howard'), ('F', 'Kevin Durant'), ('F', 'LeBron James'), ('G', 'Kobe Bryant'), ('G', 'Dwyane Wade'), ('C', "Amar'e Stoudemire"), ('F', 'Carmelo Anthony'), ('F', 'Dirk Nowitzki'), ('G', 'Steve Nash'), ('G', 'Deron Williams'), ('C', 'Andrew Bogut'), ('F', 'Tim Duncan'), ('F', 'Pau Gasol'), ('G', 'Joe Johnson'), ('G', 'Brandon Roy')], '2009': [('C', 'Dwight Howard'), ('F', 'LeBron James'), ('F', 'Dirk Nowitzki'), ('G', 'Kobe Bryant'), ('G', 'Dwyane Wade'), ('C', 'Yao Ming'), ('F', 'Tim Duncan'), ('F', 'Paul Pierce'), ('G', 'Chris Paul'), ('G', 'Brandon Roy'), ('C', "Shaquille O'Neal"), ('F', 'Carmelo Anthony'), ('F', 'Pau Gasol'), ('G', 'Chauncey Billups'), ('G', 'T ...

# %% [markdown]
# Adding the all_nba_type back into our stat dictionary:

# %%
relevantCenterData = []
relevantForwardData = []
relevantGuardData = []

for year in allNbaTeamDict:
    for position, playerName in allNbaTeamDict[str(year)]:
        if year != '2019': #exclude 2019 data for allnbateam 
            if position == 'C':
                for player in statDict[int(year)]:
                    if player['name'] == playerName:
                        relevantCenterData.append(player)
            elif position == 'F':
                for player in statDict[int(year)]:
                    if player['name'] == playerName:
                        relevantForwardData.append(player)
            elif position == 'G':
                for player in statDict[int(year)]:
                    if player['name'] == playerName:
                        relevantGuardData.append(player)

# %% [markdown]
# #### Create 2 dataframes: one for historical data (2000-2018) and one for the current season to be predicted (2019).

# %%
# 1 = All-NBA center, 2 = All-NBA forward, 3 = All-NBA guard, 0 = regular player
for playerSeason in relevantCenterData:
    for year in statDict:
        for player in statDict[int(year)]:
            if player == playerSeason:
                player['all_nba_type'] = 1
for playerSeason in relevantForwardData:
    for year in statDict:
        for player in statDict[int(year)]:
            if player == playerSeason:
                player['all_nba_type'] = 2
for playerSeason in relevantGuardData:
    for year in statDict:
        for player in statDict[int(year)]:
            if player == playerSeason:
                player['all_nba_type'] = 3
flattenedStats = []
for year in statDict:
        for player in statDict[int(year)]:
            if 'all_nba_type' not in player:
                player['all_nba_type'] = 0
            flattenedStats.append(player) #add all players to flattenedstats

historicalDf = pd.DataFrame.from_dict(flattenedStats) #df of all players with All NBA team type
currentDf = pd.DataFrame.from_dict(currentStatDict) #df of current year to be looked at 
historicalDf.describe()
# Out:
#          positions          age  games_played  games_started  minutes_played  \
# count  8344.000000  8344.000000   8344.000000    8344.000000     8344.000000
# mean      2.189238    26.686002     53.522052      26.048658     1259.842402
# std       0.755672     4.326196     24.918734      29.207754      906.613031
# min       1.000000    18.000000      1.000000       0.000000        0.000000
# 25%       2.000000    23.000000     34.000000       1.000000      418.000000
# 50%       2.000000    26.000000     61.000000      11.000000     1192.500000
# 75%       3.000000    30.000000     75.000000      52.000000     1998.000000
# max       3.000000    44.000000     85.000000      83.000000     3485.000000
#
#        made_field_goals  attempted_field_goals  made_three_point_field_goals  \
# count       8344.000000            8344.000000                   8344.000000
# mean         192.831735             426.370446                     35.304171
# std          172.890404             372.372982                     47.970925
# min            0.000000               0.000000                      0.000000
# 25%           48.000000             113.000000                      0.000000
# 50%          150.000000             340.000000                     11.000000
# 75%          294.250000             649.250000                     58.000000
# max          978.000000            2173.000000                    402.000000
#
#        attempted_three_point_field_goals  made_free_throws  ...       blocks  \
# count                        8344.000000       8344.000000  ...  8344.000000
# mean                           99.046860         95.004674  ...    25.517378
# std                           126.569228        106.555690  ...    34.153080
# min                             0.000000          0.000000  ...     0.000000
# 25%                             2.000000         18.000000  ...     4.000000
# 50%                            37.000000         59.000000  ...    13.000000
# 75%                           168.000000        134.000000  ...    32.000000
# max                           886.000000        756.000000  ...   307.000000
#
#          turnovers  personal_fouls       points  \
# count  8344.000000     8344.000000  7362.000000
# mean     72.191755      109.569271   533.053111
# std      62.724687       73.213470   481.335014
# min       0.000000        0.000000     0.000000
# 25%      21.000000       44.000000   131.000000
# 50%      58.000000      108.000000   421.000000
# 75%     107.000000      165.000000   813.000000
# max     464.000000      344.000000  2832.000000
#
#        effective_field_goal_percentage  total_points  free_throw_percentage  \
# count                      8344.000000   8344.000000            8344.000000
# mean                          0.471996    515.972315               0.700815
# std                           0.098067    471.909631               0.192948
# min                           0.000000      0.000000               0.000000
# 25%                           0.441176    123.000000               0.645161
# 50%                           0.481608    397.000000               0.750000
# 75%                           0.517550    784.000000               0.815094
# max                           1.500000   2832.000000               1.000000
#
#        team_games_played         wins  all_nba_type
# count        8344.000000  8344.000000   8344.000000
# mean           80.316035    39.927373      0.049257
# std             2.725036    12.425455      0.340406
# min            66.000000     7.000000      0.000000
# 25%            81.000000    31.000000      0.000000
# 50%            81.000000    41.000000      0.000000
# 75%            81.000000    49.000000      0.000000
# max            82.000000    72.000000      3.000000
#
# [8 rows x 25 columns]

# %%
currentDf.describe()
# Out:
#         positions         age  games_played  games_started  minutes_played  \
# count  530.000000  530.000000    530.000000     530.000000      530.000000
# mean     2.275472   25.896226     49.247170      23.207547     1121.618868
# std      0.750275    4.190477     26.048763      27.988087      838.657750
# min      1.000000   19.000000      1.000000       0.000000        1.000000
# 25%      2.000000   23.000000     27.000000       0.000000      323.500000
# 50%      2.000000   25.000000     56.000000       8.000000     1069.000000
# 75%      3.000000   29.000000     73.000000      43.750000     1836.500000
# max      3.000000   42.000000     82.000000      82.000000     3028.000000
#
#        made_field_goals  attempted_field_goals  made_three_point_field_goals  \
# count        530.000000             530.000000                    530.000000
# mean         190.683019             414.071698                     52.745283
# std          178.203049             376.879279                     60.072619
# min            0.000000               0.000000                      0.000000
# 25%           43.250000             100.250000                      4.000000
# 50%          157.000000             335.000000                     33.000000
# 75%          283.500000             618.250000                     81.000000
# max          843.000000            1909.000000                    378.000000
#
#        attempted_three_point_field_goals  made_free_throws  ...      steals  \
# count                         530.000000        530.000000  ...  530.000000
# mean                          148.569811         82.064151  ...   35.432075
# std                           159.609471         97.904875  ...   32.162749
# min                             0.000000          0.000000  ...    0.000000
# 25%                            16.000000         14.250000  ...    9.000000
# 50%                            98.000000         50.000000  ...   28.000000
# 75%                           226.500000        112.000000  ...   54.000000
# max                          1028.000000        754.000000  ...  170.000000
#
#            blocks   turnovers  personal_fouls      points  \
# count  530.000000  530.000000      530.000000   444.00000
# mean    22.990566   62.816981       97.028302   528.63964
# std     28.992827   61.375310       69.566638   513.12986
# min      0.000000    0.000000        0.000000     0.00000
# 25%      4.000000   14.250000       32.250000   107.75000
# 50%     13.000000   47.000000       95.000000   416.50000
# 75%     31.000000   91.750000      149.750000   812.00000
# max    199.000000  387.000000      292.000000  2818.00000
#
#        effective_field_goal_percentage  total_points  free_throw_percentage  \
# count                       530.000000    530.000000             530.000000
# mean                          0.500298    516.175472               0.696771
# std                           0.119148    490.433458               0.214882
# min                           0.000000      0.000000               0.000000
# 25%                           0.471813    115.000000               0.651580
# 50%                           0.511156    419.000000               0.750000
# 75%                           0.553553    759.500000               0.818182
# max                           1.500000   2818.000000               1.000000
#
#        team_games_played        wins
# count         530.000000  530.000000
# mean           80.616981   39.807547
# std             0.565631   11.875725
# min            80.000000   16.000000
# 25%            80.000000   32.000000
# 50%            81.000000   39.000000
# 75%            81.000000   49.000000
# max            82.000000   60.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# Now I have all of the All-NBA players since year 1999-2000 season and their stats, along with whether they made an All-NBA team or not, and which team they made. Now to select relevant statistics. Each player has 21 features:

# %%
relevantStatsHistoricalDf = historicalDf[['wins', 'positions','free_throw_percentage', 'turnovers', 'games_played', 'games_started', 'minutes_played', 'made_field_goals','attempted_field_goals', 'made_three_point_field_goals', 'attempted_three_point_field_goals', 'made_free_throws', 'attempted_free_throws', 'assists', 'blocks', 'steals', 'total_points', 'offensive_rebounds', 'defensive_rebounds', 'effective_field_goal_percentage', 'all_nba_type']] 

relevantStatsHistoricalDf.head()
# Out:
#    wins  positions  free_throw_percentage  turnovers  games_played  \
# 0    23          3               0.758621         26            41
# 1    40          3               0.583333         34            29
# 2    22          2               0.834275        231            81
# 3    43          3               0.666667         25            26
# 4    52          3               0.887755        204            82
#
#    games_started  minutes_played  made_field_goals  attempted_field_goals  \
# 0              0             486               120                    246
# 1             12             420                43                    111
# 2             81            3241               604                   1280
# 3              0             227                18                     56
# 4             82            3129               628                   1309
#
#    made_three_point_field_goals  ...  made_free_throws  attempted_free_throws  \
# 0                             4  ...                22                     29
# 1                             4  ...                21                     36
# 2                            12  ...               443                    531
# 3                             4  ...                12                     18
# 4                           202  ...               348                    392
#
#    assists  blocks  steals  total_points  offensive_rebounds  \
# 0       76       1       9           266                   5
# 1       22      13      14           111                  14
# 2      250      77      90          1663                 175
# 3       36       0      16            52                   0
# 4      374      20     124          1806                 101
#
#    defensive_rebounds  effective_field_goal_percentage  all_nba_type
# 0                  20                         0.495935             0
# 1                  45                         0.405405             0
# 2                 560                         0.476562             0
# 3                  25                         0.357143             0
# 4                 327                         0.556914             0
#
# [5 rows x 21 columns]

# %%
relevantStatsCurrentDf = currentDf[['wins', 'positions','free_throw_percentage', 'turnovers', 'games_played', 'games_started', 'minutes_played', 'made_field_goals','attempted_field_goals', 'made_three_point_field_goals', 'attempted_three_point_field_goals', 'made_free_throws', 'attempted_free_throws', 'assists', 'blocks', 'steals', 'total_points', 'offensive_rebounds', 'defensive_rebounds', 'effective_field_goal_percentage']] 
relevantStatsCurrentDf.head()
# Out:
#    wins  positions  free_throw_percentage  turnovers  games_played  \
# 0    49          3               0.923077         14            31
# 1    19          2               0.700000          4            10
# 2    29          3               0.777778         28            34
# 3    47          1               0.500000        135            80
# 4    39          1               0.734513        121            82
#
#    games_started  minutes_played  made_field_goals  attempted_field_goals  \
# 0              2             588                56                    157
# 1              0             123                 4                     18
# 2              1             428                38                    110
# 3             80            2669               481                    809
# 4             28            1913               280                    486
#
#    made_three_point_field_goals  attempted_three_point_field_goals  \
# 0                            41                                127
# 1                             2                                 15
# 2                            25                                 74
# 3                             0                                  2
# 4                             3                                 15
#
#    made_free_throws  attempted_free_throws  assists  blocks  steals  \
# 0                12                     13       20       6      17
# 1                 7                     10        8       4       1
# 2                 7                      9       65       5      14
# 3               146                    292      124      76     117
# 4               166                    226      184      65      71
#
#    total_points  offensive_rebounds  defensive_rebounds  \
# 0           165                   5                  43
# 1            17                   3                  22
# 2           108                  11                  49
# 3          1108                 391                 369
# 4           729                 165                 432
#
#    effective_field_goal_percentage
# 0                         0.487261
# 1                         0.277778
# 2                         0.459091
# 3                         0.594561
# 4                         0.579218

# %% [markdown]
# ### Begin training the neural network to predict the All-NBA teams

# %%
# split the data into train and test to evaluate performance of the neural net 
from sklearn.model_selection import train_test_split
y_col = 'all_nba_type' # to be removed from original Df and stored as targets
x_cols = list(relevantStatsHistoricalDf.columns.values)
x_cols.remove(y_col)

x = relevantStatsHistoricalDf[x_cols].values # all column values of df excluding allnbatype
y = relevantStatsHistoricalDf[y_col].values # corresponding targets

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2)

print(X_train)
print(Y_train)
# Out:
# [[5.60000000e+01 1.00000000e+00 3.75000000e-01 ... 2.40000000e+01
#   3.40000000e+01 3.61445783e-01]
#  [5.00000000e+01 2.00000000e+00 5.46583851e-01 ... 2.00000000e+02
#   3.26000000e+02 5.55555556e-01]
#  [2.80000000e+01 1.00000000e+00 5.00000000e-01 ... 6.00000000e+00
#   8.00000000e+00 5.00000000e-01]
#  ...
#  [1.80000000e+01 1.00000000e+00 6.80981595e-01 ... 7.00000000e+01
#   1.16000000e+02 5.98173516e-01]
#  [3.30000000e+01 2.00000000e+00 8.10344828e-01 ... 1.75000000e+02
#   4.95000000e+02 4.84825493e-01]
#  [4.80000000e+01 2.00000000e+00 7.25806452e-01 ... 9.60000000e+01
#   1.81000000e+02 4.62923729e-01]]
# [0 0 0 ... 0 0 0]

# %% [markdown]
# Normalize and preprocess the data!

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Set up a gridsearch for the MLPClassifier neural network

# %%
#build and train the actual neural net 
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(max_iter=800)
parameter_space = {
    'hidden_layer_sizes': [(50, 50, 50)], #also tested (10, 10, 10), (8), (10), (50), (50, 50), (50, 50, 50)
    'activation': ['tanh', 'relu'], #tanh seems better
    'solver': [ 'sgd'], #
    'alpha': [.0001], #.0001 best, also checked .0001 and .001
    'learning_rate_init': [.001], #.001 best learning rate so far
    'learning_rate': ['constant','adaptive'],
}

from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3)
clf.fit(X_train, Y_train)

print('Best parameters found:\n', clf.best_params_)
# Out:
# Best parameters found:
#  {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'solver': 'sgd'}

# %%
#performance of model 
predictions = clf.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(Y_test,predictions))

train_score = clf.score(X_train, Y_train)
test_score = clf.score(X_test, Y_test)
print("train_score: ", train_score)
print("test_score: ", test_score)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1622
#            1       0.71      0.71      0.71         7
#            2       0.69      0.50      0.58        18
#            3       0.75      0.55      0.63        22
#
#    micro avg       0.98      0.98      0.98      1669
#    macro avg       0.79      0.69      0.73      1669
# weighted avg       0.98      0.98      0.98      1669
#
# train_score:  0.9854681647940075
# test_score:  0.9838226482923906

# %% [markdown]
# Test 2019 data on model

# %%
curr_cols = list(relevantStatsCurrentDf.columns.values)
curr_test = relevantStatsCurrentDf[x_cols].values
curr_test = scaler.transform(curr_test) # scale testing data
allnbateam = clf.predict(curr_test)

# %% [markdown]
# Raw predictions of All-NBA teams unordered (can be more or less than 15)

# %%
#allnbateam predictions
print("Predicted team")
for player in range(len(allnbateam)):
    if allnbateam[player] == 1:
        print("center: ", currentDf.iloc[player]['name'])
    elif allnbateam[player] == 2:
        print("forward: ", currentDf.iloc[player]['name'])
    elif allnbateam[player] == 3: 
        print("guard: ", currentDf.iloc[player]['name'])

print("\n best prediction: 13 for 15 with some positional misclassification")
# Out:
# Predicted team
# forward:  Giannis Antetokounmpo
# guard:  Stephen Curry
# center:  Andre Drummond
# forward:  Kevin Durant
# forward:  Joel Embiid
# forward:  Paul George
# center:  Rudy Gobert
# guard:  James Harden
# forward:  Nikola Jokić
# forward:  Kawhi Leonard
# guard:  Damian Lillard
# guard:  Russell Westbrook
#
#  best prediction: 13 for 15 with some positional misclassification

# %% [markdown]
# Take top 3 centers, top 5 forwards, and top 5 guards to generate 3 five man All-NBA teams. Some manual reordering can be done if players are in the wrong positional group.

# %%
#0-none, 1-center, 2-forward, 3-guard 
import numpy as np

allprobs = clf.predict_proba(curr_test)
#add index as 5th column of matrix 
idx = range(0, allprobs.shape[0])
print(allprobs.shape)
idx = np.asarray(idx)
idx = np.reshape(idx, (530, 1))
allprobs = np.hstack((allprobs, idx))

allcenters = allprobs[allprobs[:,1].argsort()]
c = 1
while c < 4:
    c_index = int(allcenters[-c][4])
    print("center: ", currentDf.iloc[c_index]['name'])
    c+=1

allforwards = allprobs[allprobs[:,2].argsort()]
f = 1
while f < 9:
    f_index = int(allforwards[-f][4])
    print("forward: ", currentDf.iloc[f_index]['name'])
    f+=1

allguards = allprobs[allprobs[:,3].argsort()]
g = 1
while g < 7:
    g_index = int(allguards[-g][4])
    print("guard: ", currentDf.iloc[g_index]['name'])
    g+=1
    
#best prediction: 13 accuracy, some positional discrepancy

# %% [markdown]
# Minimize statistical data of all NBA players into 2 components using Principal Component Analysis to examine any visual trends...

# %%
#applying PCA
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
targetDf = pd.DataFrame(data = y, columns = ['targets'])
finalDf = pd.concat([principalDf, targetDf], axis = 1)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [0, 1, 2, 3]
colors = ['y', 'r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['targets'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %% [markdown]
# See notebook on feature importance for further analysis.
